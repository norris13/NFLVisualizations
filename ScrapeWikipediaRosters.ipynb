# %%
import pandas
import numpy
import requests
import bs4
from bs4 import BeautifulSoup
from pdb import set_trace
from collections import Counter

# %%
# example completed url. Note additition of '_' between sections: https://en.wikipedia.org/wiki/2000_Arizona_Cardinals_season
urlFront = "https://en.wikipedia.org/wiki/"
urlBack = "_season"


# when constructiing the url using the cities and team names, note that all spaces or hyphens need to be replaced by
# underscores in the url
# also, some teams, like the rams, have moved cities. As a result we are going to have the corresponding value for those keys
# be a list of their cities and we will surround the query with a try/catch statement
NAMETOCITY = {'Cardinals' : 'Arizona', 'Falcons' : 'Atlanta', 'Ravens' : 'Baltimore', 'Bills' : 'Buffalo', 'Panthers' : 'Carolina', 'Bears' : 'Chicago',
               'Bengals' : 'Cincinnati', 'Browns' : 'Cleveland', 'Cowboys' : 'Dallas', 'Broncos' : 'Denver', 'Lions' : 'Detroit', 'Packers' : 'Green-Bay', 
               'Texans' : 'Houston', 'Colts' : 'Indianapolis', 'Jaguars' : 'Jacksonville', 'Chiefs' : 'Kansas-City', 'Dolphins' : 'Miami', 'Vikings' : 'Minnesota',
               'Patriots' : 'New-England', 'Saints' : 'New-Orleans', 'Giants' : 'New-York', 'Jets' : 'New-York', 'Raiders' : ['Oakland', 'Las-Vegas'], 'Eagles' : 'Philadelphia',
               'Steelers' : 'Pittsburgh', 'Chargers' : ['San-Diego', 'Los-Angeles'], '49ers' : 'San-Francisco', 'Seahawks' : 'Seattle', 'Rams' : ['St.-Louis','Los-Angeles'], 'Buccaneers' : 'Tampa-bay',
               'Titans' : 'Tennessee', 'Redskins' : 'Washington'}

# Some people have 2 last names, like Kyle Vanden Bosch, the DE on the IR for the 2001 Arizona Cardinals. 
# Because of that, when I split the text by spaces and assume that the players position is the 4th element in the list
# I would find that his position is "Bosch" which obviously it isn't. It should be DE. As a result we are forming a list of 
# 'eligibile' positions. It will print out any unexpected positions so whoever is running the code can verify that no mistakes
# are made. For instance, the list below may not include "athlete" as a valid position, but upon entering the league there
# was a player named... denard robinson I think? From Michigan? who was best described as an 'athlete'. In the event that
# he is listed as such on wikipedia at any point, it will print out a list of position types that may have been overlooked
# and the user can adjust the code as necessary. 
validPositions = ["QB", "RB", "FB", "HB", 'H-B', "WR", "TE", "T", "LT", "RT", "G", "LG", "RG", "C", "OL", "DL", "NT", 
                  "DT", "DE", "RE", "LE", "OLB", "ROLB", "LOLB", "MLB", "LB", "CB", "FS", "SS", "S", "K", "P", 'H',
                 "RS", "KR", "PR", "LS", "ILB", "OT"]
# return specialist and long snapper are the two in that list that I feel might not be intuitive. 

validPositionGroups = ['quarterbacks', 'running backs', 'wide receivers', 'tight ends', 'offensive linemen', 
                      'defensive linemen', 'linebackers', 'defensive backs', 'special teams', 
                       'reserve list', 'practice squad', 'reserve lists', 'unsigned draft picks', 
                       'active/reserve lists', 'injured reserve', 'active/physically unable to perform',
                      'active/non-football injury', 'suspended', 'unrestricted free agents', 'restricted fas', 
                      'unrestricted fas', 'exclusive-rights fas']
# I added unsigned draft picks because some teams wiki pages, like the 2007 ravens, have multiple roster tables
# including preseason. So I am going to take that table down and then reassign unsigned draft picks to something else
coachingGroups = ['Head Coaches', 'Head coaches', 'Front Office', 'Front office', 'Strength and Conditioning',
                 'Strength and conditioning', 'Special Teams Coaches', 'Special teams coaches', 'Offensive Coaches', 
                  'Offensive coaches', 'Defensive Coaches', 'Defensive coaches']


# gets the HTML of the wiki page for the given team and year
def getSoup(teamName, city,  year):
    city = city.replace("-", '_')
    urlWhole = urlFront + '_' + str(year) + '_' + city + '_' + teamName + '_season'
    page = requests.get(urlWhole, headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36'})
    soup = BeautifulSoup(page.content, "html5lib")
    return soup
    
    
def getRoster(soup, city, teamName, year):
    # tempDF will store the roster for the current season for the current team and will be appended to the masterDF
    tempDF = pandas.DataFrame(columns=["Year", "City", "TeamName", "PositionGroup", "FirstName", "LastName", "JerseyNumber",
                                       "RosterStatus", "PositionOne", "PositionTwo", "PositionThree",
                                      'NameID', "NumberNameID", "ID"])
    
    # one of the teams (I forget which) had an issue where players were bolded if they were rookies and it messed everything
    # up. This line fixes it. Admittedly, I think it is fixed in a more elegant manner below because the problem is more 
    # widespread but I know this code works so I am not going to change it.
    if 'players in bold' in str(soup): return tempDF 
    
    # due to my lack of familiarity with the HTML language going into this project, I forgot the <b> tag just meant bold.
    # I was thinking it signified some sort of header in the tables. This lead to plenty of problems and I ended up trying
    # to force a bad solution (which works now!) but I'm sure this will serve as a reminder that a quick google search 
    # could have saved me countless hours spent debugging. To the point though, soup.find('b') just finds the first 'section'
    # in the table. Quarterbacks, specifically. 
    currNode = soup.find("b")
    positionGroup = currNode.text

    # while the current node is not starting a new table or is not h2 or h3, keep finding players
    # another instance where I did not fully understand what h2 and h3 signified. If this code needs to be modified down the
    # road (by me or anyone else from the NFL data community) I would probably do a better job ensuring that the soup
    # passed as an argument ends when you expect it to. The below line of code is certainly not the best way to do this.
    while (currNode.name != "table") and (currNode.name != "h2") and (currNode.name != "h3"):
        currNode = currNode.next
        # if the current node is a header... (again, b doesnt really mean that)
        if currNode.name == 'b':
            # this is the second work around for players names being bolded, and I think it makes the 'if players in bold... 
            # return' line obsolete. But I am keeping it anyway because it works and efficiency isn't my biggest concern
            # for this particular assignment. The below if/else statement accounts for when players names are bolded. 
            # since the players names are descendants (some nth degree of children) of something in the 'li' family, 
            # we can use that information to double check that whatever is bolded is a new position type and not a player
            if (currNode.parent.parent.name == 'li') or (currNode.parent.name == 'li'):
                pass
            # this line is because the panthers had a bold '(C)' to denote captain status. I think the above if statement
            # makes the else obsolete but I had this part first so I am keeping it. But at the end of the day, it 
            # is there to recognize when the position group changes from Quarterbacks to Running backs etc
            elif (currNode.text != '(C)'): 
                positionGroup = currNode.text.rstrip() #rstrip because some teams typed 'linebackers ' with a trailing space
                if positionGroup == 'Quarterbacks\'': # the jets did a possesive QBs one year for some reason
                    positionGroup = 'Quarterbacks'
        # if the current node is a List Item (like a row in the table. A player, in this case.)
        elif (currNode.name == 'li'): # that signifies we hit a new player
            # there were some empty rows that resulted in index out of bounds errors. This catches that.
            if 'class' in currNode.attrs:
                if 'mw-empty-elt' in currNode['class']:
                    continue
            
            # the text could look something like '9 Nick Foles QB'. Splitting it by spaces breaks it down into the parts we want
            # as an Eagles fan, Foles will always be #9 in my eyes.
            txt = currNode.text
            txt = txt.split()
            number = txt[0]
            if len(txt) < 3:
                continue
            firstName = txt[1]
            lastName = txt[2]
            # some players have names like 'J. J. Watt' and splitting by spaces would make it seem like the second 'J.' 
            # is their last name. This handles that case. Off the top of my head I could not think of an elegant solution
            # that would catch 100% of cases where I misname players, those will most likely have to be caught by hand
            # and fixed manually
            if ('.' in firstName) and ('.' in lastName):
                firstName = firstName + ' ' + lastName
                txt.remove(lastName)
                lastName = txt[2]
            try:
                # some people have their positions listed as 'G/T' because they are versatile. This code accounts for that
                positions = txt[3]
                finalPositions = ['NA', 'NA', 'NA']
                if positions in validPositions:
                    finalPositions[0] = positions
                    
                elif ('/' in positions): # some people have their positions listed as G/T for instance
                    positions =  positions.split('/')
                    for index in range(len(positions)):
                        if (not positions[index] in validPositions):
                            print()
                            print("WARNING: ASSUMED THAT " + positions[index] + ' WAS NOT A POSITION. PLEASE CORRECT validPositions' +
                             'AND RERUN CODE')
                            print('verify that the following information does not correspond to a player: ')
                            print(txt)
                            print('on the ' + str(year) + ' ' + teamName + '\'s wikipedia page')
                            print()
                        else:
                            finalPositions[index] = positions[index]
                            
                elif (positions in coachingGroups):
                    pass # we only want players
                
                elif (not positions in validPositions):
                    # some people have multiple last names, separated by spaces. This attempts to correct that
                    lastName = lastName + ' ' + positions
                    positions = txt[4]
                
                    finalPositions[0] = positions
                    
                
            except:
                finalPositions = [positionGroupToPosition(positionGroup, 'NA'), 'NA', 'NA'] 
                
            # Seattle added *s next to players names if they were in the pro bowl or some other award. This removes that
            lastName = lastName.replace('*', '').rstrip()
            nameID = firstName[0] + '.' + lastName
            numberNameID = str(number) + '-' + nameID
            # the row to be added for this particular player
            row = [year, city, teamName, positionGroup.lower(), firstName, lastName, number, 
                   positionGroupToPosition(positionGroup, finalPositions[0]),
                   finalPositions[0], finalPositions[1], finalPositions[2],
                  nameID, numberNameID, 'NA']
            # only add the row if the player is actually a player. Without this statement you risk some coaches sliding
            # in. A better way to do this would have been to make sure I was passing the right table earlier in the code
            # if anyone revises this code, start there. 
            if positionGroup.lower() in validPositionGroups:
                tempDF.loc[len(tempDF.index)] = row
            elif positionGroup in coachingGroups:
                pass
            # some positions were unexpected for me. Some teams had 'undrafted free agents' as a position group for instance.
            # these print statements helped me catch those issues. 
            else:
                print()
                print("should " + positionGroup + ' be considered valid?')
                print('verify that the following information does not correspond to a player: ')
                print(row)
                print('on the ' + str(year) + ' ' + teamName + '\'s wikipedia page')
                print()
    return(tempDF)    

# posArg is their header on wikipedia, like 'quarterbacks'. expected group is what they *should* be in.
# is used for unsigned draft picks
def positionGroupToPosition(posArg, expectedGroup):
    posGroup = posArg.lower()
    if posGroup == 'quarterbacks':
        return "QB"
    elif posGroup == 'running backs':
        return "RB"
    elif posGroup == 'wide receivers':
        return "WR"
    elif posGroup == 'tight ends':
        return "TE"
    elif posGroup == 'offensive linemen':
        return "OL"
    elif posGroup == 'defensive linemen':
        return "DL"
    elif posGroup == 'linebackers':
        return "LB"
    elif posGroup == 'defensive backs':
        return "DB"
    elif posGroup == 'special teams':
        return "ST"
    elif posGroup == 'injured reserve':             
        return positionToPosGroup(expectedGroup)
    elif posGroup == 'active/physically unable to perform':
        return positionToPosGroup(expectedGroup)
    elif posGroup == 'active/non-football injury':
        return positionToPosGroup(expectedGroup)
    elif posGroup == 'reserve list':             
        return positionToPosGroup(expectedGroup) 
    elif posGroup == 'reserve lists':            
        return positionToPosGroup(expectedGroup)
    elif posGroup == 'active/reserve lists':
        return positionToPosGroup(expectedGroup)
    elif posGroup == 'practice squad':   
        return positionToPosGroup(expectedGroup)
    elif posGroup == 'unsigned draft picks':
        return positionToPosGroup(expectedGroup)
    elif posGroup == 'suspended':
        return positionToPosGroup(expectedGroup)
    elif posGroup in ['unrestricted free agents', 'restricted fas', 
                      'unrestricted fas', 'exclusive-rights fas']:
        return positionToPosGroup(expectedGroup)
        

def positionToPosGroup(pos):
    if pos == 'QB':
        return 'QB'
    if (pos == 'HB') or (pos == 'RB') or (pos == 'H-B') or (pos == 'FB'):
        return 'RB'
    if pos == 'WR':
        return 'WR'
    if pos == 'TE':
        return 'TE'
    if (pos == 'T') or (pos == 'LT') or (pos == 'RT') or (pos == 'RG') or (pos == 'LG') or (pos == 'G') or (pos == 'C') or (pos == 'OL') or (pos == 'OT'):
        return 'OL'
    if (pos == 'DL') or (pos == 'NT') or (pos == 'DT') or (pos == 'DE') or (pos == 'RE') or (pos == 'LE'):
        return 'DL'
    if pos[-2:] == 'LB':
        return 'LB'
    if (pos == 'SS') or (pos == 'FS') or (pos == 'S') or (pos == 'CB'):
        return 'DB'
    if (pos == 'LS') or (pos == 'K') or (pos == 'P') or (pos == 'H'):
        return 'ST'
    if (pos == 'RS') or (pos == 'KR') or (pos == 'PR'):
        print('had to add a return specialist because of undrafted player, real group unknown')
        return 'RS'
    else:
        return 'unknown'
    
# place is 0 if it is at the start, 1 if at the end
def printStars(place):
    if place == 0:
        print('\n*********************************************')
        
    else:
        print('*********************************************\n')

# %%
masterDataFrame = pandas.DataFrame(columns=["Year", "City", "TeamName", "PositionGroup", "FirstName", "LastName", 
                                            "JerseyNumber", "RosterStatus", "PositionOne", "PositionTwo", "PositionThree",
                                           'NameID', "NumberNameID", "ID"])
# note that the range function goes from year A to year B-1. So range(2000,2020) will do seasons 2000-2019. 
keyVals = list(NAMETOCITY.keys())
oneTeam = ['Eagles']
for teamName in keyVals:
    for year in range(1999,2020):
        print('scraping ' + teamName + ' for year ' + str(year))
        
        # the code on either end of this if statement is more or less identical, but I am not going ot fix that by creating
        # a new function and using that to make it more readable right now. Maybe on a future version of this code if I come
        # back to it. 
        if (type(NAMETOCITY[teamName]) == list):
            for city in NAMETOCITY[teamName]:
                try:
                    page = getSoup(teamName, city, year)
                except: 
                    print("\n WARNING: FAILED TO GET HTML FOR " + teamName + " FOR THE YEAR " + str(year) + '\n')

                tbs = page.findAll("tbody")


                # this is where many of my issues came from. Do not do this. This is not the best way to find the
                # table you are looking for.All of the tables (i think) are headed like '2019 Philadelphia Eagles final roster'
                # just search for that and you will never get any coaches or weird position groups like UDFAs
                containsQBs = list()
                for elem in tbs:
                    if "Quarterbacks" in elem.text:
                            containsQBs.append(elem)
                            
                # the below code tries to get the roster. If it fails (for any of the reasons above) then we try again with
                # the next table. As far as im aware the most it will have to go through this for loop is 4 times. 
                try:
                    for possibleRosterTable in containsQBs:
                            #rosterAsSoup = containsQBs[1] #From the pages I checked it was always the second element in the list, hopefully that stays true
                        roster = getRoster(possibleRosterTable, city, teamName, year)
                        if type(roster) == None:
                            print("WARNING: FAILED TO GET ROSTER FOR " + teamName + " FOR THE YEAR " + str(year))
                            print("\t it is recommended that you see how widespread the issue is and whether or not it makes sense to" + 
                                     "just copy those rosters by hand. One known potential issue is if the wikipedia structure doesn't" + 
                                     "match the expected layout")
                        elif len(roster.index) == 0:
                            pass #case where it isnt none, it is just an empty dataframe
                        else: 
                            break
                except:
                    pass
                if (len(roster.index) < 30) or (len(roster.index) > 90):
                    printStars(0)
                    print('number of rows added:' + str(len(roster.index)) + ' for ' + teamName + ' in ' + str(year))
                    printStars(1)

                masterDataFrame = masterDataFrame.append(roster, ignore_index = True)
        else:
            city = NAMETOCITY[teamName]
            try:
                page = getSoup(teamName, city, year)
            except: 
                print("\n WARNING: FAILED TO GET HTML FOR " + teamName + " FOR THE YEAR " + str(year) + '\n')
                
            tbs = page.findAll("tbody")

            
            containsQBs = list()
            for elem in tbs:
                if "Quarterbacks" in elem.text:
                        containsQBs.append(elem)
            try:
                for possibleRosterTable in containsQBs:
                        #rosterAsSoup = containsQBs[1] #From the pages I checked it was always the second element in the list, hopefully that stays true
                    roster = getRoster(possibleRosterTable, city, teamName, year)
                    if type(roster) == None:
                        print("WARNING: FAILED TO GET ROSTER FOR " + teamName + " FOR THE YEAR " + str(year))
                        print("\t it is recommended that you see how widespread the issue is and whether or not it makes sense to" + 
                                 "just copy those rosters by hand. One known potential issue is if the wikipedia structure doesn't" + 
                                 "match the expected layout")
                    elif len(roster.index) == 0:
                        pass #case where it isnt none, it is just an empty dataframe
                    else: 
                        break
            except:
                pass
            if len(roster.index) == 0:
                print('number of rows added:' + str(len(roster.index)) + ' for ' + teamName + ' in ' + str(year))
                
            if (len(roster.index) < 30) or (len(roster.index) > 90):
                    printStars(0)
                    print('number of rows added:' + str(len(roster.index)) + ' for ' + teamName + ' in ' + str(year))
                    printStars(1)

            
            masterDataFrame = masterDataFrame.append(roster, ignore_index = True)
            
print('*********** DONE *********************')
# Out:
# scraping Cardinals for year 1999
# scraping Cardinals for year 2000
# scraping Cardinals for year 2001
# scraping Cardinals for year 2002
# scraping Cardinals for year 2003
# scraping Cardinals for year 2004
# scraping Cardinals for year 2005
# scraping Cardinals for year 2006
# scraping Cardinals for year 2007
# scraping Cardinals for year 2008
# scraping Cardinals for year 2009
# scraping Cardinals for year 2010
# scraping Cardinals for year 2011
# scraping Cardinals for year 2012
# scraping Cardinals for year 2013
# scraping Cardinals for year 2014
# scraping Cardinals for year 2015
# scraping Cardinals for year 2016
# scraping Cardinals for year 2017
# scraping Cardinals for year 2018
# scraping Cardinals for year 2019
#
# WARNING: ASSUMED THAT Fellowship WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Bill', 'Bidwill', 'Coaching', 'Fellowship/Running', 'Backs', '–', 'Don', 'Shumpert']
# on the 2019 Cardinals's wikipedia page
#
#
# WARNING: ASSUMED THAT Running WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Bill', 'Bidwill', 'Coaching', 'Fellowship/Running', 'Backs', '–', 'Don', 'Shumpert']
# on the 2019 Cardinals's wikipedia page
#
# scraping Falcons for year 1999
#
# WARNING: ASSUMED THAT Personnel WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Personnel/College', '–', 'Reed', 'Johnson']
# on the 1999 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT College WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Personnel/College', '–', 'Reed', 'Johnson']
# on the 1999 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT Personnel WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Personnel/Pro', '–', 'Chuck', 'Connor']
# on the 1999 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT Pro WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Personnel/Pro', '–', 'Chuck', 'Connor']
# on the 1999 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT Coach WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'to', 'Head', 'Coach/Pro', 'Personnel', '–', 'Marvin', 'Bass']
# on the 1999 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT Pro WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'to', 'Head', 'Coach/Pro', 'Personnel', '–', 'Marvin', 'Bass']
# on the 1999 Falcons's wikipedia page
#
# scraping Falcons for year 2000
#
# WARNING: ASSUMED THAT Personnel WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Personnel/College', '–', 'Reed', 'Johnson']
# on the 2000 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT College WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Personnel/College', '–', 'Reed', 'Johnson']
# on the 2000 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT Personnel WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Personnel/Pro', '–', 'Chuck', 'Connor']
# on the 2000 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT Pro WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Personnel/Pro', '–', 'Chuck', 'Connor']
# on the 2000 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT Coach WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'to', 'Head', 'Coach/Pro', 'Personnel', '–', 'Marvin', 'Bass']
# on the 2000 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT Pro WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'to', 'Head', 'Coach/Pro', 'Personnel', '–', 'Marvin', 'Bass']
# on the 2000 Falcons's wikipedia page
#
# scraping Falcons for year 2001
#
# WARNING: ASSUMED THAT Personnel WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Personnel/College', '–', 'Reed', 'Johnson']
# on the 2001 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT College WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Personnel/College', '–', 'Reed', 'Johnson']
# on the 2001 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT Personnel WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Personnel/Pro', '–', 'Les', 'Snead']
# on the 2001 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT Pro WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Personnel/Pro', '–', 'Les', 'Snead']
# on the 2001 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT Coach WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'to', 'Head', 'Coach/Pro', 'Personnel', '–', 'Marvin', 'Bass']
# on the 2001 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT Pro WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'to', 'Head', 'Coach/Pro', 'Personnel', '–', 'Marvin', 'Bass']
# on the 2001 Falcons's wikipedia page
#
# scraping Falcons for year 2002
#
# WARNING: ASSUMED THAT Coach WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'to', 'Head', 'Coach/Pro', 'Personnel', '–', 'Marvin', 'Bass']
# on the 2002 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT Pro WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'to', 'Head', 'Coach/Pro', 'Personnel', '–', 'Marvin', 'Bass']
# on the 2002 Falcons's wikipedia page
#
# scraping Falcons for year 2003
#
# WARNING: ASSUMED THAT Coach WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'to', 'Head', 'Coach/Pro', 'Personnel', '–', 'Marvin', 'Bass']
# on the 2003 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT Pro WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'to', 'Head', 'Coach/Pro', 'Personnel', '–', 'Marvin', 'Bass']
# on the 2003 Falcons's wikipedia page
#
# scraping Falcons for year 2004
# scraping Falcons for year 2005
# scraping Falcons for year 2006
# scraping Falcons for year 2007
# scraping Falcons for year 2008
# scraping Falcons for year 2009
# scraping Falcons for year 2010
# scraping Falcons for year 2011
# scraping Falcons for year 2012
# scraping Falcons for year 2013
# scraping Falcons for year 2014
# scraping Falcons for year 2015
# scraping Falcons for year 2016
# scraping Falcons for year 2017
# scraping Falcons for year 2018
# scraping Falcons for year 2019
#
# WARNING: ASSUMED THAT coordinator WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Defensive', 'passing', 'game', 'coordinator/secondary', '–', 'Jerome', 'Henderson']
# on the 2019 Falcons's wikipedia page
#
#
# WARNING: ASSUMED THAT secondary WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Defensive', 'passing', 'game', 'coordinator/secondary', '–', 'Jerome', 'Henderson']
# on the 2019 Falcons's wikipedia page
# scraping Ravens for year 1999
# scraping Ravens for year 2000
# scraping Ravens for year 2001
# scraping Ravens for year 2002
# scraping Ravens for year 2003
# scraping Ravens for year 2004
# scraping Ravens for year 2005
# scraping Ravens for year 2006
# scraping Ravens for year 2007
# scraping Ravens for year 2008
# scraping Ravens for year 2009
# scraping Ravens for year 2010
# scraping Ravens for year 2011
# scraping Ravens for year 2012
# scraping Ravens for year 2013
# scraping Ravens for year 2014
#
# WARNING: ASSUMED THAT  WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Defensive', 'Quality', 'Control', '/', 'Linebackers', 'Assistant', '–', 'Matt', 'Weiss']
# on the 2014 Ravens's wikipedia page
#
#
# WARNING: ASSUMED THAT  WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Defensive', 'Quality', 'Control', '/', 'Linebackers', 'Assistant', '–', 'Matt', 'Weiss']
# on the 2014 Ravens's wikipedia page
#
# scraping Ravens for year 2015
# scraping Ravens for year 2016
# scraping Ravens for year 2017
# scraping Ravens for year 2018
# scraping Ravens for year 2019
#
# WARNING: ASSUMED THAT coordinator WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'head', 'coach/pass', 'coordinator/wide', 'receivers', '–', 'David', 'Culley']
# on the 2019 Ravens's wikipedia page
#
#
# WARNING: ASSUMED THAT wide WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'head', 'coach/pass', 'coordinator/wide', 'receivers', '–', 'David', 'Culley']
# on the 2019 Ravens's wikipedia page
#
# scraping Bills for year 1999
# scraping Bills for year 2000
# scraping Bills for year 2001
# scraping Bills for year 2002
# scraping Bills for year 2003
# scraping Bills for year 2004
# scraping Bills for year 2005
# scraping Bills for year 2006
# scraping Bills for year 2007
# scraping Bills for year 2008
# scraping Bills for year 2009
# scraping Bills for year 2010
# scraping Bills for year 2011
# scraping Bills for year 2012
# scraping Bills for year 2013
# scraping Bills for year 2014
# scraping Bills for year 2015
# scraping Bills for year 2016
# scraping Bills for year 2017
# scraping Bills for year 2018
# scraping Bills for year 2019
# scraping Panthers for year 1999
# scraping Panthers for year 2000
# scraping Panthers for year 2001
# scraping Panthers for year 2002
# scraping Panthers for year 2003
# scraping Panthers for year 2004
# scraping Panthers for year 2005
# scraping Panthers for year 2006
# scraping Panthers for year 2007
# scraping Panthers for year 2008
# scraping Panthers for year 2009
# scraping Panthers for year 2010
# scraping Panthers for year 2011
# scraping Panthers for year 2012
# scraping Panthers for year 2013
# scraping Panthers for year 2014
# scraping Panthers for year 2015
# scraping Panthers for year 2016
# scraping Panthers for year 2017
# scraping Panthers for year 2018
# scraping Panthers for year 2019
# scraping Bears for year 1999
# scraping Bears for year 2000
# scraping Bears for year 2001
# scraping Bears for year 2002
# scraping Bears for year 2003
# scraping Bears for year 2004
# scraping Bears for year 2005
# scraping Bears for year 2006
# scraping Bears for year 2007
# scraping Bears for year 2008
# scraping Bears for year 2009
# scraping Bears for year 2010
# scraping Bears for year 2011
# scraping Bears for year 2012
# scraping Bears for year 2013
# scraping Bears for year 2014
# scraping Bears for year 2015
# scraping Bears for year 2016
# scraping Bears for year 2017
# scraping Bears for year 2018
# scraping Bears for year 2019
# scraping Bengals for year 1999
# scraping Bengals for year 2000
# scraping Bengals for year 2001
# scraping Bengals for year 2002
# scraping Bengals for year 2003
# scraping Bengals for year 2004
# scraping Bengals for year 2005
# scraping Bengals for year 2006
# scraping Bengals for year 2007
# scraping Bengals for year 2008
#
# *********************************************
# number of rows added:18 for Bengals in 2008
# *********************************************
#
# scraping Bengals for year 2009
# scraping Bengals for year 2010
# scraping Bengals for year 2011
# scraping Bengals for year 2012
# scraping Bengals for year 2013
# scraping Bengals for year 2014
# scraping Bengals for year 2015
# scraping Bengals for year 2016
# scraping Bengals for year 2017
# scraping Bengals for year 2018
# scraping Bengals for year 2019
# scraping Browns for year 1999
# scraping Browns for year 2000
# scraping Browns for year 2001
# scraping Browns for year 2002
# scraping Browns for year 2003
# scraping Browns for year 2004
# scraping Browns for year 2005
# scraping Browns for year 2006
# scraping Browns for year 2007
# scraping Browns for year 2008
# scraping Browns for year 2009
# scraping Browns for year 2010
# scraping Browns for year 2011
# scraping Browns for year 2012
#
# *********************************************
# number of rows added:91 for Browns in 2012
# *********************************************
#
# scraping Browns for year 2013
# scraping Browns for year 2014
# scraping Browns for year 2015
# scraping Browns for year 2016
# scraping Browns for year 2017
# scraping Browns for year 2018
# scraping Browns for year 2019
#
# WARNING: ASSUMED THAT assistant WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Strength', 'and', 'conditioning', 'assistant/sports', 'science', '–', 'Josh', 'Christovich']
# on the 2019 Browns's wikipedia page
#
#
# WARNING: ASSUMED THAT sports WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Strength', 'and', 'conditioning', 'assistant/sports', 'science', '–', 'Josh', 'Christovich']
# on the 2019 Browns's wikipedia page
#
# scraping Cowboys for year 1999
# scraping Cowboys for year 2000
# scraping Cowboys for year 2001
# scraping Cowboys for year 2002
# scraping Cowboys for year 2003
# scraping Cowboys for year 2004
# scraping Cowboys for year 2005
# scraping Cowboys for year 2006
# scraping Cowboys for year 2007
# scraping Cowboys for year 2008
# scraping Cowboys for year 2009
# scraping Cowboys for year 2010
# scraping Cowboys for year 2011
#
# *********************************************
# number of rows added:91 for Cowboys in 2011
# *********************************************
#
# scraping Cowboys for year 2012
# scraping Cowboys for year 2013
#
# *********************************************
# number of rows added:91 for Cowboys in 2013
# *********************************************
#
# scraping Cowboys for year 2014
#
# *********************************************
# number of rows added:95 for Cowboys in 2014
# *********************************************
#
# scraping Cowboys for year 2015
#
# *********************************************
# number of rows added:97 for Cowboys in 2015
# *********************************************
#
# scraping Cowboys for year 2016
#
# *********************************************
# number of rows added:94 for Cowboys in 2016
# *********************************************
#
# scraping Cowboys for year 2017
#
# *********************************************
# number of rows added:93 for Cowboys in 2017
# *********************************************
#
# scraping Cowboys for year 2018
#
# *********************************************
# number of rows added:92 for Cowboys in 2018
# *********************************************
#
# scraping Cowboys for year 2019
# scraping Broncos for year 1999
# scraping Broncos for year 2000
# scraping Broncos for year 2001
# scraping Broncos for year 2002
# scraping Broncos for year 2003
# scraping Broncos for year 2004
# scraping Broncos for year 2005
# scraping Broncos for year 2006
# scraping Broncos for year 2007
# scraping Broncos for year 2008
# number of rows added:0 for Broncos in 2008
#
# *********************************************
# number of rows added:0 for Broncos in 2008
# *********************************************
#
# scraping Broncos for year 2009
# scraping Broncos for year 2010
# scraping Broncos for year 2011
# scraping Broncos for year 2012
# scraping Broncos for year 2013
# scraping Broncos for year 2014
# scraping Broncos for year 2015
# scraping Broncos for year 2016
# scraping Broncos for year 2017
#
# WARNING: ASSUMED THAT Operations WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['President', 'of', 'Football', 'Operations/General', 'Manager', '–', 'John', 'Elway']
# on the 2017 Broncos's wikipedia page
#
#
# WARNING: ASSUMED THAT General WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['President', 'of', 'Football', 'Operations/General', 'Manager', '–', 'John', 'Elway']
# on the 2017 Broncos's wikipedia page
#
# scraping Broncos for year 2018
#
# WARNING: ASSUMED THAT operations WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['President', 'of', 'football', 'operations/general', 'manager', '–', 'John', 'Elway']
# on the 2018 Broncos's wikipedia page
#
#
# WARNING: ASSUMED THAT general WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['President', 'of', 'football', 'operations/general', 'manager', '–', 'John', 'Elway']
# on the 2018 Broncos's wikipedia page
#
# scraping Broncos for year 2019
#
# WARNING: ASSUMED THAT Operations WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['President', 'of', 'Football', 'Operations/General', 'Manager', '–', 'John', 'Elway']
# on the 2019 Broncos's wikipedia page
#
#
# WARNING: ASSUMED THAT General WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['President', 'of', 'Football', 'Operations/General', 'Manager', '–', 'John', 'Elway']
# on the 2019 Broncos's wikipedia page
#
# scraping Lions for year 1999
# scraping Lions for year 2000
# scraping Lions for year 2001
# scraping Lions for year 2002
# had to add a return specialist because of undrafted player, real group unknown
# scraping Lions for year 2003
# scraping Lions for year 2004
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2004, 'Detroit', 'Lions', 'notations', '2004', 'Rookie', 'R:', None, None, 'NA', 'NA', '2.Rookie', 'R:-2.Rookie', 'NA']
# on the 2004 Lions's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2004, 'Detroit', 'Lions', 'notations', '2004', 'Undrafted Rookie', 'UR:', None, None, 'NA', 'NA', '2.Undrafted Rookie', 'UR:-2.Undrafted Rookie', 'NA']
# on the 2004 Lions's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2004, 'Detroit', 'Lions', 'notations', 'players', 'are not', 'Italicized', None, 'on', 'NA', 'NA', 'p.are not', 'Italicized-p.are not', 'NA']
# on the 2004 Lions's wikipedia page
#
# scraping Lions for year 2005
# scraping Lions for year 2006
# scraping Lions for year 2007
# scraping Lions for year 2008
# scraping Lions for year 2009
# scraping Lions for year 2010
# scraping Lions for year 2011
# scraping Lions for year 2012
# scraping Lions for year 2013
# scraping Lions for year 2014
# scraping Lions for year 2015
# scraping Lions for year 2016
# scraping Lions for year 2017
# scraping Lions for year 2018
# scraping Lions for year 2019
#
# WARNING: ASSUMED THAT assistantship WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['WCF', 'minority', 'coaching', 'assistantship/defense', '–', 'Billy', 'Yates']
# on the 2019 Lions's wikipedia page
#
#
# WARNING: ASSUMED THAT defense WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['WCF', 'minority', 'coaching', 'assistantship/defense', '–', 'Billy', 'Yates']
# on the 2019 Lions's wikipedia page
#
#
# WARNING: ASSUMED THAT assistantship WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['WCF', 'minority', 'coaching', 'assistantship/offense', 'and', 'special', 'teams', '–', 'Leon', 'Washington']
# on the 2019 Lions's wikipedia page
#
#
# WARNING: ASSUMED THAT offense WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['WCF', 'minority', 'coaching', 'assistantship/offense', 'and', 'special', 'teams', '–', 'Leon', 'Washington']
# on the 2019 Lions's wikipedia page
#
# scraping Packers for year 1999
#
# WARNING: ASSUMED THAT Finance WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Finance/Football', 'Operations', '–', 'Andrew', 'Brandt']
# on the 1999 Packers's wikipedia page
#
#
# WARNING: ASSUMED THAT Football WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Finance/Football', 'Operations', '–', 'Andrew', 'Brandt']
# on the 1999 Packers's wikipedia page
#
# scraping Packers for year 2000
# scraping Packers for year 2001
# scraping Packers for year 2002
# scraping Packers for year 2003
#
# WARNING: ASSUMED THAT Manager WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Executive', 'Vice', 'President/General', 'Manager/Head', 'Coach', '–', 'Mike', 'Sherman']
# on the 2003 Packers's wikipedia page
#
#
# WARNING: ASSUMED THAT Head WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Executive', 'Vice', 'President/General', 'Manager/Head', 'Coach', '–', 'Mike', 'Sherman']
# on the 2003 Packers's wikipedia page
#
# scraping Packers for year 2004
#
# WARNING: ASSUMED THAT Manager WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Executive', 'Vice', 'President/General', 'Manager/Head', 'Coach', '–', 'Mike', 'Sherman']
# on the 2004 Packers's wikipedia page
#
#
# WARNING: ASSUMED THAT Head WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Executive', 'Vice', 'President/General', 'Manager/Head', 'Coach', '–', 'Mike', 'Sherman']
# on the 2004 Packers's wikipedia page
#
# scraping Packers for year 2005
# scraping Packers for year 2006
# scraping Packers for year 2007
# scraping Packers for year 2008
# scraping Packers for year 2009
# scraping Packers for year 2010
# scraping Packers for year 2011
# scraping Packers for year 2012
# scraping Packers for year 2013
#
# WARNING: ASSUMED THAT Manager WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Executive', 'Vice', 'President/General', 'Manager/Director', 'of', 'Football', 'Operations', '–', 'Ted', 'Thompson']
# on the 2013 Packers's wikipedia page
#
#
# WARNING: ASSUMED THAT Director WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Executive', 'Vice', 'President/General', 'Manager/Director', 'of', 'Football', 'Operations', '–', 'Ted', 'Thompson']
# on the 2013 Packers's wikipedia page
#
# scraping Packers for year 2014
#
# WARNING: ASSUMED THAT Manager WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Executive', 'Vice', 'President/General', 'Manager/Director', 'of', 'Football', 'Operations', '–', 'Ted', 'Thompson']
# on the 2014 Packers's wikipedia page
#
#
# WARNING: ASSUMED THAT Director WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Executive', 'Vice', 'President/General', 'Manager/Director', 'of', 'Football', 'Operations', '–', 'Ted', 'Thompson']
# on the 2014 Packers's wikipedia page
#
# scraping Packers for year 2015
# WARNING: ASSUMED THAT Manager WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Executive', 'Vice', 'President/General', 'Manager/Director', 'of', 'Football', 'Operations', '–', 'Ted', 'Thompson']
# on the 2015 Packers's wikipedia page
#
#
# WARNING: ASSUMED THAT Director WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Executive', 'Vice', 'President/General', 'Manager/Director', 'of', 'Football', 'Operations', '–', 'Ted', 'Thompson']
# on the 2015 Packers's wikipedia page
#
# scraping Packers for year 2016
# scraping Packers for year 2017
# scraping Packers for year 2018
# scraping Packers for year 2019
# scraping Texans for year 1999
# scraping Texans for year 2000
# scraping Texans for year 2001
# scraping Texans for year 2002
# scraping Texans for year 2003
# scraping Texans for year 2004
# scraping Texans for year 2005
# scraping Texans for year 2006
# scraping Texans for year 2007
# scraping Texans for year 2008
# scraping Texans for year 2009
# scraping Texans for year 2010
# scraping Texans for year 2011
# scraping Texans for year 2012
# scraping Texans for year 2013
# scraping Texans for year 2014
# scraping Texans for year 2015
# scraping Texans for year 2016
# scraping Texans for year 2017
# scraping Texans for year 2018
# scraping Texans for year 2019
#
# WARNING: ASSUMED THAT conditioning WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'strength', 'and', 'conditioning/Sports', 'Science', 'Coordinator', '–', 'Jason', 'George']
# on the 2019 Texans's wikipedia page
#
#
# WARNING: ASSUMED THAT Sports WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'strength', 'and', 'conditioning/Sports', 'Science', 'Coordinator', '–', 'Jason', 'George']
# on the 2019 Texans's wikipedia page
#
#
# WARNING: ASSUMED THAT conditioning WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'strength', 'and', 'conditioning/Performance', 'Therapist', '–', 'Billy', 'Voltaire']
# on the 2019 Texans's wikipedia page
#
#
# WARNING: ASSUMED THAT Performance WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'strength', 'and', 'conditioning/Performance', 'Therapist', '–', 'Billy', 'Voltaire']
# on the 2019 Texans's wikipedia page
#
# scraping Colts for year 1999
# scraping Colts for year 2000
# scraping Colts for year 2001
# scraping Colts for year 2002
# scraping Colts for year 2003
# scraping Colts for year 2004
# scraping Colts for year 2005
# scraping Colts for year 2006
# scraping Colts for year 2007
# scraping Colts for year 2008
# scraping Colts for year 2009
# scraping Colts for year 2010
# scraping Colts for year 2011
# scraping Colts for year 2012
# scraping Colts for year 2013
# scraping Colts for year 2014
# scraping Colts for year 2015
# scraping Colts for year 2016
# scraping Colts for year 2017
# scraping Colts for year 2018
# scraping Colts for year 2019
# scraping Jaguars for year 1999
# scraping Jaguars for year 2000
# scraping Jaguars for year 2001
# scraping Jaguars for year 2002
# scraping Jaguars for year 2003
# scraping Jaguars for year 2004
# scraping Jaguars for year 2005
# scraping Jaguars for year 2006
# scraping Jaguars for year 2007
# scraping Jaguars for year 2008
# scraping Jaguars for year 2009
# scraping Jaguars for year 2010
# scraping Jaguars for year 2011
# scraping Jaguars for year 2012
# scraping Jaguars for year 2013
# scraping Jaguars for year 2014
# scraping Jaguars for year 2015
# scraping Jaguars for year 2016
# scraping Jaguars for year 2017
# scraping Jaguars for year 2018
# scraping Jaguars for year 2019
# scraping Chiefs for year 1999
# scraping Chiefs for year 2000
# scraping Chiefs for year 2001
# scraping Chiefs for year 2002
# scraping Chiefs for year 2003
# scraping Chiefs for year 2004
# scraping Chiefs for year 2005
# scraping Chiefs for year 2006
# scraping Chiefs for year 2007
# scraping Chiefs for year 2008
# scraping Chiefs for year 2009
# scraping Chiefs for year 2010
# scraping Chiefs for year 2011
# scraping Chiefs for year 2012
# scraping Chiefs for year 2013
# scraping Chiefs for year 2014
# scraping Chiefs for year 2015
# scraping Chiefs for year 2016
# scraping Chiefs for year 2017
# scraping Chiefs for year 2018
# scraping Chiefs for year 2019
# scraping Dolphins for year 1999
# scraping Dolphins for year 2000
# scraping Dolphins for year 2001
# scraping Dolphins for year 2002
# scraping Dolphins for year 2003
# scraping Dolphins for year 2004
# scraping Dolphins for year 2005
# scraping Dolphins for year 2006
#
# WARNING: ASSUMED THAT Development WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Development/Special', 'Assistant', 'to', 'the', 'Head', 'Coach', '–', 'John', 'Gamble']
# on the 2006 Dolphins's wikipedia page
#
#
# WARNING: ASSUMED THAT Special WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Player', 'Development/Special', 'Assistant', 'to', 'the', 'Head', 'Coach', '–', 'John', 'Gamble']
# on the 2006 Dolphins's wikipedia page
#
# scraping Dolphins for year 2007
# scraping Dolphins for year 2008
# scraping Dolphins for year 2009
# scraping Dolphins for year 2010
# scraping Dolphins for year 2011
# scraping Dolphins for year 2012
# scraping Dolphins for year 2013
# scraping Dolphins for year 2014
# scraping Dolphins for year 2015
# scraping Dolphins for year 2016
# scraping Dolphins for year 2017
# scraping Dolphins for year 2018
# scraping Dolphins for year 2019
#
# WARNING: ASSUMED THAT Coordinator WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Defensive', 'Pass', 'Game', 'Coordinator/Cornerbacks', '–', 'Josh', 'Boyer']
# on the 2019 Dolphins's wikipedia page
#
#
# WARNING: ASSUMED THAT Cornerbacks WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Defensive', 'Pass', 'Game', 'Coordinator/Cornerbacks', '–', 'Josh', 'Boyer']
# on the 2019 Dolphins's wikipedia page
#
# scraping Vikings for year 1999
# scraping Vikings for year 2000
# scraping Vikings for year 2001
# scraping Vikings for year 2002
# scraping Vikings for year 2003
# scraping Vikings for year 2004
# scraping Vikings for year 2005
# scraping Vikings for year 2006
# scraping Vikings for year 2007
# scraping Vikings for year 2008
#
# WARNING: ASSUMED THAT Assistant WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'wide', 'receivers/Offensive', 'Assistant/Assistant', 'Special', 'Teams', '–', 'Chad', "O'Shea"]
# on the 2008 Vikings's wikipedia page
#
#
# WARNING: ASSUMED THAT Assistant WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'wide', 'receivers/Offensive', 'Assistant/Assistant', 'Special', 'Teams', '–', 'Chad', "O'Shea"]
# on the 2008 Vikings's wikipedia page
#
# scraping Vikings for year 2009
# scraping Vikings for year 2010
# scraping Vikings for year 2011
# scraping Vikings for year 2012
# scraping Vikings for year 2013
# scraping Vikings for year 2014
# scraping Vikings for year 2015
# scraping Vikings for year 2016
#
# WARNING: ASSUMED THAT 9-17) WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Offensive', 'Coordinator', '(weeks', '9-17)/Tight', 'Ends', '–', 'Pat', 'Shurmur']
# on the 2016 Vikings's wikipedia page
#
#
# WARNING: ASSUMED THAT Tight WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Offensive', 'Coordinator', '(weeks', '9-17)/Tight', 'Ends', '–', 'Pat', 'Shurmur']
# on the 2016 Vikings's wikipedia page
# scraping Vikings for year 2017
# scraping Vikings for year 2018
# scraping Vikings for year 2019
# scraping Patriots for year 1999
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [1999, 'New-England', 'Patriots', 'notations', '1999', 'Rookie', 'R:', None, None, 'NA', 'NA', '1.Rookie', 'R:-1.Rookie', 'NA']
# on the 1999 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [1999, 'New-England', 'Patriots', 'notations', '1999', 'Undrafted Rookie', 'UR:', None, None, 'NA', 'NA', '1.Undrafted Rookie', 'UR:-1.Undrafted Rookie', 'NA']
# on the 1999 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [1999, 'New-England', 'Patriots', 'notations', 'players', 'are not', 'Italicized', None, 'on', 'NA', 'NA', 'p.are not', 'Italicized-p.are not', 'NA']
# on the 1999 Patriots's wikipedia page
#
# scraping Patriots for year 2000
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2000, 'New-England', 'Patriots', 'notations', '2000', 'Rookie', 'R:', None, None, 'NA', 'NA', '2.Rookie', 'R:-2.Rookie', 'NA']
# on the 2000 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2000, 'New-England', 'Patriots', 'notations', '2000', 'Undrafted Rookie', 'UR:', None, None, 'NA', 'NA', '2.Undrafted Rookie', 'UR:-2.Undrafted Rookie', 'NA']
# on the 2000 Patriots's wikipedia page
#
# scraping Patriots for year 2001
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2001, 'New-England', 'Patriots', 'notations', '2001', 'Rookie', 'R:', None, None, 'NA', 'NA', '2.Rookie', 'R:-2.Rookie', 'NA']
# on the 2001 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2001, 'New-England', 'Patriots', 'notations', '2001', 'Undrafted Rookie', 'UR:', None, None, 'NA', 'NA', '2.Undrafted Rookie', 'UR:-2.Undrafted Rookie', 'NA']
# on the 2001 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2001, 'New-England', 'Patriots', 'notations', 'players', 'are not', 'Italicized', None, 'on', 'NA', 'NA', 'p.are not', 'Italicized-p.are not', 'NA']
# on the 2001 Patriots's wikipedia page
#
# scraping Patriots for year 2002
# scraping Patriots for year 2003
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2003, 'New-England', 'Patriots', 'notations', '2003', 'Rookie', 'R:', None, None, 'NA', 'NA', '2.Rookie', 'R:-2.Rookie', 'NA']
# on the 2003 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2003, 'New-England', 'Patriots', 'notations', '2003', 'Undrafted Rookie', 'UR:', None, None, 'NA', 'NA', '2.Undrafted Rookie', 'UR:-2.Undrafted Rookie', 'NA']
# on the 2003 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2003, 'New-England', 'Patriots', 'notations', 'players', 'are not', 'Italicized', None, 'on', 'NA', 'NA', 'p.are not', 'Italicized-p.are not', 'NA']
# on the 2003 Patriots's wikipedia page
#
# scraping Patriots for year 2004
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2004, 'New-England', 'Patriots', 'notations', '2004', 'Rookie', 'R:', None, None, 'NA', 'NA', '2.Rookie', 'R:-2.Rookie', 'NA']
# on the 2004 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2004, 'New-England', 'Patriots', 'notations', '2004', 'Undrafted Rookie', 'UR:', None, None, 'NA', 'NA', '2.Undrafted Rookie', 'UR:-2.Undrafted Rookie', 'NA']
# on the 2004 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2004, 'New-England', 'Patriots', 'notations', 'players', 'are not', 'Italicized', None, 'on', 'NA', 'NA', 'p.are not', 'Italicized-p.are not', 'NA']
# on the 2004 Patriots's wikipedia page
#
# scraping Patriots for year 2005
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2005, 'New-England', 'Patriots', 'notations', '2005', 'Rookie', 'R:', None, None, 'NA', 'NA', '2.Rookie', 'R:-2.Rookie', 'NA']
# on the 2005 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2005, 'New-England', 'Patriots', 'notations', '2005', 'Undrafted Rookie', 'UR:', None, None, 'NA', 'NA', '2.Undrafted Rookie', 'UR:-2.Undrafted Rookie', 'NA']
# on the 2005 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2005, 'New-England', 'Patriots', 'notations', 'players', 'are not', 'Italicized', None, 'on', 'NA', 'NA', 'p.are not', 'Italicized-p.are not', 'NA']
# on the 2005 Patriots's wikipedia page
#
# scraping Patriots for year 2006
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2006, 'New-England', 'Patriots', 'notations', '2006', 'Rookie', 'R:', None, None, 'NA', 'NA', '2.Rookie', 'R:-2.Rookie', 'NA']
# on the 2006 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2006, 'New-England', 'Patriots', 'notations', '2006', 'Undrafted Rookie', 'UR:', None, None, 'NA', 'NA', '2.Undrafted Rookie', 'UR:-2.Undrafted Rookie', 'NA']
# on the 2006 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2006, 'New-England', 'Patriots', 'notations', 'players', 'are not', 'Italicized', None, 'onthe', 'NA', 'NA', 'p.are not', 'Italicized-p.are not', 'NA']
# on the 2006 Patriots's wikipedia page
#
# scraping Patriots for year 2007
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2007, 'New-England', 'Patriots', 'notations', '2007', 'Rookie', 'R:', None, None, 'NA', 'NA', '2.Rookie', 'R:-2.Rookie', 'NA']
# on the 2007 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2007, 'New-England', 'Patriots', 'notations', '2007', 'Undrafted Rookie', 'UR:', None, None, 'NA', 'NA', '2.Undrafted Rookie', 'UR:-2.Undrafted Rookie', 'NA']
# on the 2007 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2007, 'New-England', 'Patriots', 'notations', 'players', 'are not', 'Italicized', None, 'on', 'NA', 'NA', 'p.are not', 'Italicized-p.are not', 'NA']
# on the 2007 Patriots's wikipedia page
#
# scraping Patriots for year 2008
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2008, 'New-England', 'Patriots', 'notations', '2008', 'Rookie', 'R:', None, None, 'NA', 'NA', '2.Rookie', 'R:-2.Rookie', 'NA']
# on the 2008 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2008, 'New-England', 'Patriots', 'notations', '2008', 'Undrafted Rookie', 'UR:', None, None, 'NA', 'NA', '2.Undrafted Rookie', 'UR:-2.Undrafted Rookie', 'NA']
# on the 2008 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2008, 'New-England', 'Patriots', 'notations', 'players', 'are not', 'Italicized', None, 'on', 'NA', 'NA', 'p.are not', 'Italicized-p.are not', 'NA']
# on the 2008 Patriots's wikipedia page
#
# scraping Patriots for year 2009
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2009, 'New-England', 'Patriots', 'notations', '2009', 'Rookie', 'R:', None, None, 'NA', 'NA', '2.Rookie', 'R:-2.Rookie', 'NA']
# on the 2009 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2009, 'New-England', 'Patriots', 'notations', '2009', 'Undrafted Rookie', 'UR:', None, None, 'NA', 'NA', '2.Undrafted Rookie', 'UR:-2.Undrafted Rookie', 'NA']
# on the 2009 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2009, 'New-England', 'Patriots', 'notations', 'players', 'are not', 'Italicized', None, 'on', 'NA', 'NA', 'p.are not', 'Italicized-p.are not', 'NA']
# on the 2009 Patriots's wikipedia page
#
# scraping Patriots for year 2010
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2010, 'New-England', 'Patriots', 'notations', '2010', 'Rookie', 'R:', None, None, 'NA', 'NA', '2.Rookie', 'R:-2.Rookie', 'NA']
# on the 2010 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2010, 'New-England', 'Patriots', 'notations', '2010', 'Undrafted Rookie', 'UR:', None, None, 'NA', 'NA', '2.Undrafted Rookie', 'UR:-2.Undrafted Rookie', 'NA']
# on the 2010 Patriots's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2010, 'New-England', 'Patriots', 'notations', 'players', 'are not', 'Italicized', None, 'on', 'NA', 'NA', 'p.are not', 'Italicized-p.are not', 'NA']
# on the 2010 Patriots's wikipedia page
#
# scraping Patriots for year 2011
# scraping Patriots for year 2012
# scraping Patriots for year 2013
# scraping Patriots for year 2014
# scraping Patriots for year 2015
# scraping Patriots for year 2016
# scraping Patriots for year 2017
#
# *********************************************
# number of rows added:92 for Patriots in 2017
# *********************************************
#
# scraping Patriots for year 2018
# scraping Patriots for year 2019
#
# *********************************************
# number of rows added:92 for Patriots in 2019
# *********************************************
#
# scraping Saints for year 1999
# scraping Saints for year 2000
# scraping Saints for year 2001
# scraping Saints for year 2002
# scraping Saints for year 2003
# scraping Saints for year 2004
# scraping Saints for year 2005
# scraping Saints for year 2006
# scraping Saints for year 2007
# scraping Saints for year 2008
# scraping Saints for year 2009
# scraping Saints for year 2010
#
# should Coaching Assistants be considered valid?
# verify that the following information does not correspond to a player:
# [2010, 'New-Orleans', 'Saints', 'coaching assistants', 'Smith,', 'Marcus Ungaro,', 'Frank', None, 'Blake', 'NA', 'NA', 'S.Marcus Ungaro,', 'Frank-S.Marcus Ungaro,', 'NA']
# on the 2010 Saints's wikipedia page
#
# scraping Saints for year 2011
#
# should Coaching Assistants be considered valid?
# verify that the following information does not correspond to a player:
# [2011, 'New-Orleans', 'Saints', 'coaching assistants', 'Smith,', 'Marcus Ungaro,', 'Frank', None, 'Blake', 'NA', 'NA', 'S.Marcus Ungaro,', 'Frank-S.Marcus Ungaro,', 'NA']
# on the 2011 Saints's wikipedia page
#
# scraping Saints for year 2012
# scraping Saints for year 2013
# scraping Saints for year 2014
# scraping Saints for year 2015
# had to add a return specialist because of undrafted player, real group unknown
# scraping Saints for year 2016
# scraping Saints for year 2017
#
# *********************************************
# number of rows added:91 for Saints in 2017
# *********************************************
#
# scraping Saints for year 2018
# scraping Saints for year 2019
# scraping Giants for year 1999
# scraping Giants for year 2000
# scraping Giants for year 2001
# scraping Giants for year 2002
# scraping Giants for year 2003
# scraping Giants for year 2004
# scraping Giants for year 2005
# scraping Giants for year 2006
# scraping Giants for year 2007
#
# should Special Team Coaches be considered valid?
# verify that the following information does not correspond to a player:
# [2007, 'New-York', 'Giants', 'special team coaches', 'Teams', 'Coordinator –', 'Special', None, 'Tom', 'NA', 'NA', 'T.Coordinator –', 'Special-T.Coordinator –', 'NA']
# on the 2007 Giants's wikipedia page
#
#
# should Special Team Coaches be considered valid?
# verify that the following information does not correspond to a player:
# [2007, 'New-York', 'Giants', 'special team coaches', 'Special', 'Teams –', 'Assistant', None, 'Thomas', 'NA', 'NA', 'S.Teams –', 'Assistant-S.Teams –', 'NA']
# on the 2007 Giants's wikipedia page
#
# scraping Giants for year 2008
#
# should Special Team Coaches be considered valid?
# verify that the following information does not correspond to a player:
# [2008, 'New-York', 'Giants', 'special team coaches', 'Teams', 'Coordinator –', 'Special', None, 'Tom', 'NA', 'NA', 'T.Coordinator –', 'Special-T.Coordinator –', 'NA']
# on the 2008 Giants's wikipedia page
#
#
# should Special Team Coaches be considered valid?
# verify that the following information does not correspond to a player:
# [2008, 'New-York', 'Giants', 'special team coaches', 'Special', 'Teams –', 'Assistant', None, 'Thomas', 'NA', 'NA', 'S.Teams –', 'Assistant-S.Teams –', 'NA']
# on the 2008 Giants's wikipedia page
#
# scraping Giants for year 2009
# scraping Giants for year 2010
# scraping Giants for year 2011
# scraping Giants for year 2012
# scraping Giants for year 2013
# scraping Giants for year 2014
# scraping Giants for year 2015
# scraping Giants for year 2016
#
# WARNING: ASSUMED THAT Operations WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Football', 'Operations/Special', 'Projects', '–', 'Martin', 'Mayhew']
# on the 2016 Giants's wikipedia page
#
#
# WARNING: ASSUMED THAT Special WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Football', 'Operations/Special', 'Projects', '–', 'Martin', 'Mayhew']
# on the 2016 Giants's wikipedia page
#
# scraping Giants for year 2017
#
# WARNING: ASSUMED THAT Nutrition WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Director', 'of', 'Performance', 'Nutrition/Assistant', 'Strength', 'and', 'Conditioning', '–', 'Pratik', 'Patel']
# ...
# scraping Steelers for year 2009
# scraping Steelers for year 2010
# scraping Steelers for year 2011
# scraping Steelers for year 2012
# scraping Steelers for year 2013
# scraping Steelers for year 2014
# scraping Steelers for year 2015
# scraping Steelers for year 2016
# scraping Steelers for year 2017
# scraping Steelers for year 2018
# scraping Steelers for year 2019
# scraping Chargers for year 1999
# scraping Chargers for year 2000
# scraping Chargers for year 2001
# scraping Chargers for year 2002
# scraping Chargers for year 2003
# scraping Chargers for year 2004
# scraping Chargers for year 2005
# scraping Chargers for year 2006
# scraping Chargers for year 2007
# scraping Chargers for year 2008
# scraping Chargers for year 2009
# scraping Chargers for year 2010
# scraping Chargers for year 2011
# scraping Chargers for year 2012
# scraping Chargers for year 2013
# scraping Chargers for year 2014
# scraping Chargers for year 2015
# scraping Chargers for year 2016
# scraping Chargers for year 2017
# scraping Chargers for year 2018
# scraping Chargers for year 2019
# scraping 49ers for year 1999
# scraping 49ers for year 2000
# scraping 49ers for year 2001
# scraping 49ers for year 2002
# scraping 49ers for year 2003
# scraping 49ers for year 2004
# scraping 49ers for year 2005
# scraping 49ers for year 2006
# scraping 49ers for year 2007
# scraping 49ers for year 2008
# scraping 49ers for year 2009
# scraping 49ers for year 2010
# scraping 49ers for year 2011
# scraping 49ers for year 2012
# scraping 49ers for year 2013
# scraping 49ers for year 2014
# scraping 49ers for year 2015
# scraping 49ers for year 2016
# scraping 49ers for year 2017
# scraping 49ers for year 2018
# scraping 49ers for year 2019
# scraping Seahawks for year 1999
# scraping Seahawks for year 2000
# scraping Seahawks for year 2001
# scraping Seahawks for year 2002
# scraping Seahawks for year 2003
# scraping Seahawks for year 2004
# scraping Seahawks for year 2005
# scraping Seahawks for year 2006
# had to add a return specialist because of undrafted player, real group unknown
# scraping Seahawks for year 2007
# scraping Seahawks for year 2008
# scraping Seahawks for year 2009
#
# WARNING: ASSUMED THAT Operations WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['President', 'of', 'Football', 'Operations/General', 'Manager', '–', 'Tim', 'Ruskell']
# on the 2009 Seahawks's wikipedia page
#
#
# WARNING: ASSUMED THAT General WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['President', 'of', 'Football', 'Operations/General', 'Manager', '–', 'Tim', 'Ruskell']
# on the 2009 Seahawks's wikipedia page
#
# scraping Seahawks for year 2010
# scraping Seahawks for year 2011
# scraping Seahawks for year 2012
# scraping Seahawks for year 2013
# scraping Seahawks for year 2014
# scraping Seahawks for year 2015
# scraping Seahawks for year 2016
# scraping Seahawks for year 2017
# scraping Seahawks for year 2018
# scraping Seahawks for year 2019
# scraping Rams for year 1999
# scraping Rams for year 2000
#
# WARNING: ASSUMED THAT  WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Associate', 'Head', 'Coach', '/', 'Wide', 'Receivers', '–', 'Al', 'Saunders']
# on the 2000 Rams's wikipedia page
#
#
# WARNING: ASSUMED THAT  WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Associate', 'Head', 'Coach', '/', 'Wide', 'Receivers', '–', 'Al', 'Saunders']
# on the 2000 Rams's wikipedia page
#
#
# WARNING: ASSUMED THAT  WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'Head', 'Coach', '/', 'Offensive', 'Line', '–', 'John', 'Matsko']
# on the 2000 Rams's wikipedia page
#
#
# WARNING: ASSUMED THAT  WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'Head', 'Coach', '/', 'Offensive', 'Line', '–', 'John', 'Matsko']
# on the 2000 Rams's wikipedia page
#
# scraping Rams for year 2001
#
# WARNING: ASSUMED THAT  WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Associate', 'Head', 'Coach', '/', 'Offensive', 'Coordinator', '/', 'Running', 'Backs', '–', 'Bobby', 'Jackson']
# on the 2001 Rams's wikipedia page
#
#
# WARNING: ASSUMED THAT  WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Associate', 'Head', 'Coach', '/', 'Offensive', 'Coordinator', '/', 'Running', 'Backs', '–', 'Bobby', 'Jackson']
# on the 2001 Rams's wikipedia page
#
#
# WARNING: ASSUMED THAT  WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'Head', 'Coach', '/', 'Offensive', 'Line', '–', 'John', 'Matsko']
# on the 2001 Rams's wikipedia page
#
#
# WARNING: ASSUMED THAT  WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'Head', 'Coach', '/', 'Offensive', 'Line', '–', 'John', 'Matsko']
# on the 2001 Rams's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2001, 'St.-Louis', 'Rams', 'notations', '2001', 'Rookie', 'R:', None, None, 'NA', 'NA', '2.Rookie', 'R:-2.Rookie', 'NA']
# on the 2001 Rams's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2001, 'St.-Louis', 'Rams', 'notations', '2001', 'Undrafted Rookie', 'UR:', None, None, 'NA', 'NA', '2.Undrafted Rookie', 'UR:-2.Undrafted Rookie', 'NA']
# on the 2001 Rams's wikipedia page
#
#
# should Notations be considered valid?
# verify that the following information does not correspond to a player:
# [2001, 'St.-Louis', 'Rams', 'notations', 'players', 'are not', 'Italicized', None, 'on', 'NA', 'NA', 'p.are not', 'Italicized-p.are not', 'NA']
# on the 2001 Rams's wikipedia page
#
# scraping Rams for year 2002
# scraping Rams for year 2003
# scraping Rams for year 2004
# scraping Rams for year 2005
# scraping Rams for year 2006
# scraping Rams for year 2007
# scraping Rams for year 2008
# scraping Rams for year 2009
# scraping Rams for year 2010
# scraping Rams for year 2011
# scraping Rams for year 2012
# scraping Rams for year 2013
# scraping Rams for year 2014
# scraping Rams for year 2015
# scraping Rams for year 2016
# scraping Rams for year 2017
# scraping Rams for year 2018
# scraping Rams for year 2019
# had to add a return specialist because of undrafted player, real group unknown
# scraping Buccaneers for year 1999
# scraping Buccaneers for year 2000
# scraping Buccaneers for year 2001
# scraping Buccaneers for year 2002
# scraping Buccaneers for year 2003
# scraping Buccaneers for year 2004
# scraping Buccaneers for year 2005
# scraping Buccaneers for year 2006
# scraping Buccaneers for year 2007
# scraping Buccaneers for year 2008
# scraping Buccaneers for year 2009
# scraping Buccaneers for year 2010
# scraping Buccaneers for year 2011
# scraping Buccaneers for year 2012
# scraping Buccaneers for year 2013
# scraping Buccaneers for year 2014
# scraping Buccaneers for year 2015
# scraping Buccaneers for year 2016
# scraping Buccaneers for year 2017
# scraping Buccaneers for year 2018
# scraping Buccaneers for year 2019
# scraping Titans for year 1999
#
# WARNING: ASSUMED THAT Board WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Founder/Owner/Chairman', 'of', 'the', 'Board/CEO', '–', 'Bud', 'Adams']
# on the 1999 Titans's wikipedia page
#
#
# WARNING: ASSUMED THAT CEO WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Founder/Owner/Chairman', 'of', 'the', 'Board/CEO', '–', 'Bud', 'Adams']
# on the 1999 Titans's wikipedia page
#
# scraping Titans for year 2000
# scraping Titans for year 2001
# scraping Titans for year 2002
#
# WARNING: ASSUMED THAT Board WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Founder/Owner/Chairman', 'of', 'the', 'Board/CEO', '–', 'Bud', 'Adams']
# on the 2002 Titans's wikipedia page
#
#
# WARNING: ASSUMED THAT CEO WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Founder/Owner/Chairman', 'of', 'the', 'Board/CEO', '–', 'Bud', 'Adams']
# on the 2002 Titans's wikipedia page
# scraping Titans for year 2003
#
# WARNING: ASSUMED THAT Board WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Founder/Owner/Chairman', 'of', 'the', 'Board/CEO', '–', 'Bud', 'Adams']
# on the 2003 Titans's wikipedia page
#
#
# WARNING: ASSUMED THAT CEO WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Founder/Owner/Chairman', 'of', 'the', 'Board/CEO', '–', 'Bud', 'Adams']
# on the 2003 Titans's wikipedia page
#
# scraping Titans for year 2004
#
# WARNING: ASSUMED THAT Board WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Founder/Owner/Chairman', 'of', 'the', 'Board/President/CEO', '–', 'Bud', 'Adams']
# on the 2004 Titans's wikipedia page
#
#
# WARNING: ASSUMED THAT President WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Founder/Owner/Chairman', 'of', 'the', 'Board/President/CEO', '–', 'Bud', 'Adams']
# on the 2004 Titans's wikipedia page
#
#
# WARNING: ASSUMED THAT CEO WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Founder/Owner/Chairman', 'of', 'the', 'Board/President/CEO', '–', 'Bud', 'Adams']
# on the 2004 Titans's wikipedia page
#
# scraping Titans for year 2005
#
# WARNING: ASSUMED THAT Board WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Founder/Owner/Chairman', 'of', 'the', 'Board/President/CEO', '–', 'Bud', 'Adams']
# on the 2005 Titans's wikipedia page
#
#
# WARNING: ASSUMED THAT President WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Founder/Owner/Chairman', 'of', 'the', 'Board/President/CEO', '–', 'Bud', 'Adams']
# on the 2005 Titans's wikipedia page
#
#
# WARNING: ASSUMED THAT CEO WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Founder/Owner/Chairman', 'of', 'the', 'Board/President/CEO', '–', 'Bud', 'Adams']
# on the 2005 Titans's wikipedia page
#
# scraping Titans for year 2006
# scraping Titans for year 2007
# scraping Titans for year 2008
# scraping Titans for year 2009
# scraping Titans for year 2010
#
# WARNING: ASSUMED THAT President WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Senior', 'Executive', 'Vice', 'President/General', 'Counsel', '–', 'Steve', 'Underwood']
# on the 2010 Titans's wikipedia page
#
#
# WARNING: ASSUMED THAT General WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Senior', 'Executive', 'Vice', 'President/General', 'Counsel', '–', 'Steve', 'Underwood']
# on the 2010 Titans's wikipedia page
#
#
# should Strength and Conditioning Coaches be considered valid?
# verify that the following information does not correspond to a player:
# [2010, 'Tennessee', 'Titans', 'strength and conditioning coaches', 'Head', 'Coach/Strength and', 'Assistant', None, 'Conditioning', 'NA', 'NA', 'H.Coach/Strength and', 'Assistant-H.Coach/Strength and', 'NA']
# on the 2010 Titans's wikipedia page
#
# scraping Titans for year 2011
#
# should Strength and Conditioning Coaches be considered valid?
# verify that the following information does not correspond to a player:
# [2011, 'Tennessee', 'Titans', 'strength and conditioning coaches', 'Head', 'Coach/Strength and', 'Assistant', None, 'Conditioning', 'NA', 'NA', 'H.Coach/Strength and', 'Assistant-H.Coach/Strength and', 'NA']
# on the 2011 Titans's wikipedia page
#
# scraping Titans for year 2012
#
# WARNING: ASSUMED THAT President WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Senior', 'Executive', 'Vice', 'President/Chief', 'Operating', 'Officer', '–', 'Mike', 'Reinfeldt']
# on the 2012 Titans's wikipedia page
#
#
# WARNING: ASSUMED THAT Chief WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Senior', 'Executive', 'Vice', 'President/Chief', 'Operating', 'Officer', '–', 'Mike', 'Reinfeldt']
# on the 2012 Titans's wikipedia page
#
# scraping Titans for year 2013
# scraping Titans for year 2014
# scraping Titans for year 2015
# scraping Titans for year 2016
# scraping Titans for year 2017
# scraping Titans for year 2018
# scraping Titans for year 2019
# scraping Redskins for year 1999
# scraping Redskins for year 2000
# scraping Redskins for year 2001
# scraping Redskins for year 2002
# scraping Redskins for year 2003
# scraping Redskins for year 2004
#
# WARNING: ASSUMED THAT Teams WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Quality', 'Control', 'Special', 'Teams/Defensive', 'Assistant', '–', 'Kirk', 'Olivadotti']
# on the 2004 Redskins's wikipedia page
#
#
# WARNING: ASSUMED THAT Defensive WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Quality', 'Control', 'Special', 'Teams/Defensive', 'Assistant', '–', 'Kirk', 'Olivadotti']
# on the 2004 Redskins's wikipedia page
#
# scraping Redskins for year 2005
# scraping Redskins for year 2006
# scraping Redskins for year 2007
# scraping Redskins for year 2008
# scraping Redskins for year 2009
# scraping Redskins for year 2010
#
# should Coaching Assistants be considered valid?
# verify that the following information does not correspond to a player:
# [2010, 'Washington', 'Redskins', 'coaching assistants', 'Applebaum,', 'Richmond Flowers', 'Matt', None, 'III', 'NA', 'NA', 'A.Richmond Flowers', 'Matt-A.Richmond Flowers', 'NA']
# on the 2010 Redskins's wikipedia page
#
# scraping Redskins for year 2011
#
# should Coaching Assistants be considered valid?
# verify that the following information does not correspond to a player:
# [2011, 'Washington', 'Redskins', 'coaching assistants', 'Flowers', 'III', 'Richmond', None, None, 'NA', 'NA', 'F.III', 'Richmond-F.III', 'NA']
# on the 2011 Redskins's wikipedia page
#
# scraping Redskins for year 2012
# scraping Redskins for year 2013
# scraping Redskins for year 2014
# scraping Redskins for year 2015
# scraping Redskins for year 2016
#
# WARNING: ASSUMED THAT conditioning WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'strength', 'and', 'conditioning/skill', 'development', '–', 'Joe', 'Kim']
# on the 2016 Redskins's wikipedia page
#
#
# WARNING: ASSUMED THAT skill WAS NOT A POSITION. PLEASE CORRECT validPositionsAND RERUN CODE
# verify that the following information does not correspond to a player:
# ['Assistant', 'strength', 'and', 'conditioning/skill', 'development', '–', 'Joe', 'Kim']
# on the 2016 Redskins's wikipedia page
#
# scraping Redskins for year 2017
# scraping Redskins for year 2018
# scraping Redskins for year 2019
# *********** DONE *********************

# %%
masterDataFrame.to_csv('1999_2019_NFL_ROSTERS.csv')

# %%
masterDataFrame.shape
# Out:
# (50308, 14)

# %%
Counter(masterDataFrame[(masterDataFrame.Year == 2009) & (masterDataFrame.TeamName == 'Falcons')].PositionGroup)
# Out:
# Counter({'quarterbacks': 3,
#          'running backs': 6,
#          'wide receivers': 5,
#          'tight ends': 4,
#          'offensive linemen': 8,
#          'defensive linemen': 9,
#          'linebackers': 6,
#          'defensive backs': 8,
#          'special teams': 4,
#          'reserve lists': 11,
#          'practice squad': 11})

# %%
wilson = masterDataFrame.LastName[1]

# %%
testList = [1,2,3,4]
for number in testList:
    if number == 3:
        continue
    print(number)
# Out:
# 1
# 2
# 4

# %%
masterDataFrame[(masterDataFrame.TeamName == 'Ravens') &
               (masterDataFrame.Year == 2009)]
# Out:
#     Year       City TeamName      PositionGroup  FirstName     LastName  \
# 0   2009  Baltimore   Ravens       quarterbacks       John         Beck
# 1   2009  Baltimore   Ravens       quarterbacks        Joe       Flacco
# 2   2009  Baltimore   Ravens       quarterbacks       Troy        Smith
# 3   2009  Baltimore   Ravens      running backs      Jason         Cook
# 4   2009  Baltimore   Ravens      running backs       Matt     Lawrence
# 5   2009  Baltimore   Ravens      running backs     Le'Ron      McClain
# 6   2009  Baltimore   Ravens      running backs      Jalen      Parmele
# 7   2009  Baltimore   Ravens      running backs     Cedric      Peerman
# 8   2009  Baltimore   Ravens      running backs        Ray         Rice
# 9   2009  Baltimore   Ravens     wide receivers       Drew      Bennett
# 10  2009  Baltimore   Ravens     wide receivers       Mark      Clayton
# 11  2009  Baltimore   Ravens     wide receivers      Biren         Ealy
# 12  2009  Baltimore   Ravens     wide receivers     Jayson       Foster
# 13  2009  Baltimore   Ravens     wide receivers     Justin       Harper
# 14  2009  Baltimore   Ravens     wide receivers    Derrick        Mason
# 15  2009  Baltimore   Ravens     wide receivers       Eron        Riley
# 16  2009  Baltimore   Ravens     wide receivers     Marcus        Smith
# 17  2009  Baltimore   Ravens     wide receivers     Kelley   Washington
# 18  2009  Baltimore   Ravens     wide receivers      Ernie  Wheelwright
# 19  2009  Baltimore   Ravens     wide receivers  Demetrius     Williams
# 20  2009  Baltimore   Ravens         tight ends      Davon         Drew
# 21  2009  Baltimore   Ravens         tight ends       Todd         Heap
# 22  2009  Baltimore   Ravens         tight ends      Edgar        Jones
# 23  2009  Baltimore   Ravens         tight ends      L. J.        Smith
# 24  2009  Baltimore   Ravens         tight ends      Isaac       Smolko
# 25  2009  Baltimore   Ravens  offensive linemen       Matt         Birk
# 26  2009  Baltimore   Ravens  offensive linemen      Chris      Chester
# 27  2009  Baltimore   Ravens  offensive linemen      Oniel      Cousins
# 28  2009  Baltimore   Ravens  offensive linemen      Robby        Felix
# 29  2009  Baltimore   Ravens  offensive linemen      Jared      Gaither
# ..   ...        ...      ...                ...        ...          ...
# 51  2009  Baltimore   Ravens        linebackers     Jarret      Johnson
# 52  2009  Baltimore   Ravens        linebackers       Paul       Kruger
# 53  2009  Baltimore   Ravens        linebackers        Ray        Lewis
# 54  2009  Baltimore   Ravens        linebackers     Jameel      McClain
# 55  2009  Baltimore   Ravens        linebackers      Jason     Phillips
# 56  2009  Baltimore   Ravens        linebackers    Terrell        Suggs
# 57  2009  Baltimore   Ravens        linebackers     Willie   VanDeSteeg
# 58  2009  Baltimore   Ravens    defensive backs      Chris         Carr
# 59  2009  Baltimore   Ravens    defensive backs  Domonique     Foxworth
# 60  2009  Baltimore   Ravens    defensive backs      K. J.       Gerard
# 61  2009  Baltimore   Ravens    defensive backs      Dawan       Landry
# 62  2009  Baltimore   Ravens    defensive backs    Derrick       Martin
# 63  2009  Baltimore   Ravens    defensive backs     Haruki     Nakamura
# 64  2009  Baltimore   Ravens    defensive backs       Evan      Oglesby
# 65  2009  Baltimore   Ravens    defensive backs         Ed         Reed
# 66  2009  Baltimore   Ravens    defensive backs     Samari        Rolle
# 67  2009  Baltimore   Ravens    defensive backs      Frank       Walker
# 68  2009  Baltimore   Ravens    defensive backs     Fabian   Washington
# 69  2009  Baltimore   Ravens    defensive backs  Lardarius         Webb
# 70  2009  Baltimore   Ravens    defensive backs        Tom    Zbikowski
# 71  2009  Baltimore   Ravens      special teams     Graham         Gano
# 72  2009  Baltimore   Ravens      special teams    Stephen     Hauschka
# 73  2009  Baltimore   Ravens      special teams       Matt       Katula
# 74  2009  Baltimore   Ravens      special teams        Sam         Koch
# 75  2009  Baltimore   Ravens      reserve lists      Yamon       Figurs
# 76  2009  Baltimore   Ravens      reserve lists        Ben       Grubbs
# 77  2009  Baltimore   Ravens      reserve lists     Willis      McGahee
# 78  2009  Baltimore   Ravens      reserve lists       Greg         Ryan
# 79  2009  Baltimore   Ravens      reserve lists        Lou      Saucedo
# 80  2009  Baltimore   Ravens      reserve lists    Marshal        Yanda
#
#    JerseyNumber RosterStatus PositionOne PositionTwo PositionThree
# 0            12           QB          QB          NA            NA
# 1             5           QB          QB          NA            NA
# 2            10           QB          QB          NA            NA
# 3            39           RB          FB          NA            NA
# 4            32           RB          RB          NA            NA
# 5            33           RB          FB          NA            NA
# 6            34           RB          RB          NA            NA
# 7            38           RB          RB          NA            NA
# 8            27           RB          RB          NA            NA
# 9            18           WR          WR          NA            NA
# 10           89           WR          WR          NA            NA
# 11            8           WR          WR          NA            NA
# 12           --           WR          WR          NA            NA
# 13           14           WR          WR          NA            NA
# 14           85           WR          WR          NA            NA
# 15           13           WR          WR          NA            NA
# 16           81           WR          WR          NA            NA
# 17           15           WR          WR          NA            NA
# 18           17           WR          WR          NA            NA
# 19           87           WR          WR          NA            NA
# 20           83           TE          TE          NA            NA
# 21           86           TE          TE          NA            NA
# 22           84           TE          TE          NA            NA
# 23           82           TE          TE          NA            NA
# 24           80           TE          TE          NA            NA
# 25           77           OL           C          NA            NA
# 26           65           OL           G          NA            NA
# 27           64           OL           T          NA            NA
# 28           60           OL           G          NA            NA
# 29           71           OL           T          NA            NA
# ..          ...          ...         ...         ...           ...
# 51           95           LB         OLB          NA            NA
# 52           99           LB         OLB          NA            NA
# 53           52           LB         ILB          NA            NA
# 54           53           LB         ILB          NA            NA
# 55           58           LB         ILB          NA            NA
# 56           55           LB         OLB          NA            NA
# 57           68           LB         OLB          NA            NA
# 58           30           DB          CB          NA            NA
# 59           24           DB          CB          NA            NA
# 60           40           DB          CB          NA            NA
# 61           26           DB          SS          NA            NA
# 62           29           DB          CB          NA            NA
# 63           43           DB          FS          NA            NA
# 64           25           DB          CB          NA            NA
# 65           20           DB          FS          NA            NA
# 66           22           DB          CB          NA            NA
# 67           41           DB          CB          NA            NA
# 68           31           DB          CB          NA            NA
# 69           21           DB          CB          NA            NA
# 70           28           DB          SS          NA            NA
# 71            7           ST           K          NA            NA
# 72            6           ST           K          NA            NA
# 73           70           ST          LS          NA            NA
# 74            4           ST           P          NA            NA
# 75           16           IR          WR          NA            NA
# 76           66           IR           G          NA            NA
# 77           23           IR          RB          NA            NA
# 78           59           IR           C          NA            NA
# 79           79           IR          OT          NA            NA
# 80           73           IR           G          NA            NA
#
# [81 rows x 11 columns]

# %%
lbString = 'LB'
lbString[-2:]
# Out:
# 'LB'

# %%
testSoup = getSoup(city='Seattle', teamName='Seahawks', year = 2013)

# %%
testSoup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en"><head>
# <meta charset="utf-8"/>
# <title>2013 Seattle Seahawks season - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"24129ca0-5b4c-468b-9d57-6b732cecac47","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"2013_Seattle_Seahawks_season","wgTitle":"2013 Seattle Seahawks season","wgCurRevisionId":959355204,"wgRevisionId":959355204,"wgArticleId":37982259,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Pages using deprecated image syntax","Articles that may contain original research from January 2014","All articles that may contain original research","All articles with specifically marked weasel-worded phrases",
# "Articles with specifically marked weasel-worded phrases from January 2014","2013 National Football League season by team","Seattle Seahawks seasons","NFC West championship seasons","National Football Conference championship seasons","Super Bowl champion seasons","2013 in sports in Washington (state)"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"2013_Seattle_Seahawks_season","wgRelevantArticleId":37982259,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":
# "wikipedia","wgWikibaseItemId":"Q2657605","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.makeCollapsible.styles":"ready","mediawiki.toc.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.makeCollapsible","mediawiki.toc","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups",
# "ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});</script>
# <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cmediawiki.toc.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
# <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
# <meta content="MediaWiki 1.35.0-wmf.37" name="generator"/>
# <meta content="origin" name="referrer"/>
# <meta content="origin-when-crossorigin" name="referrer"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/5/53/Seattle_seahawks_uniforms_2012-2017.png" property="og:image"/>
# <link href="/w/index.php?title=2013_Seattle_Seahawks_season&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
# <link href="/w/index.php?title=2013_Seattle_Seahawks_season&amp;action=edit" rel="edit" title="Edit this page"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
# <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
# <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
# <link href="/w/index.php?title=Special:RecentChanges&amp;feed=atom" rel="alternate" title="Wikipedia Atom feed" type="application/atom+xml"/>
# <link href="https://en.wikipedia.org/wiki/2013_Seattle_Seahawks_season" rel="canonical"/>
# <link href="//login.wikimedia.org" rel="dns-prefetch"/>
# <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
# <!--[if lt IE 9]><script src="/w/resources/lib/html5shiv/html5shiv.js"></script><![endif]-->
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-2013_Seattle_Seahawks_season rootpage-2013_Seattle_Seahawks_season skin-vector action-view skin-vector-legacy">
# <div class="noprint" id="mw-page-base"></div>
# <div class="noprint" id="mw-head-base"></div>
# <div class="mw-body" id="content" role="main">
# 	<a id="top"></a>
# 		<div class="mw-body-content" id="siteNotice"><!-- CentralNotice --></div>
# 	<div class="mw-indicators mw-body-content">
# 	</div>
# 	<h1 class="firstHeading" id="firstHeading" lang="en">2013 Seattle Seahawks season</h1>
#
# 	<div class="mw-body-content" id="bodyContent">
# 		<div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>
# 		<div id="contentSub"></div>
#
#
# 		<div id="jump-to-nav"></div>
# 		<a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
# 		<a class="mw-jump-link" href="#p-search">Jump to search</a>
# 		<div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><div class="mw-parser-output"><div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">38th season in franchise history; first Super Bowl win</div>
# <table class="infobox vcard" style="width:22em;width: 23em"><tbody><tr><th class="note" colspan="2" style="text-align:center;font-size:125%;font-weight:bold;font-size:100%; background: #002244; color: #FFFFFF; -moz-box-shadow: inset 2.5px 2.5px 0 #69BE28, inset -2.5px -2.5px 0 #69BE28; -webkit-box-shadow: inset 2.5px 2.5px 0 #69BE28, inset -2.5px -2.5px 0 #69BE28; box-shadow: inset 2.5px 2.5px 0 #69BE28, inset -2.5px -2.5px 0 #69BE28;; line-height: 1.5em;">2013 <span class="fn org">Seattle Seahawks</span> season</th></tr><tr><th scope="row">Head coach</th><td class="agent"><a href="/wiki/Pete_Carroll" title="Pete Carroll">Pete Carroll</a></td></tr><tr><th scope="row">General manager</th><td class="fn"><a href="/wiki/John_Schneider_(American_football_executive)" title="John Schneider (American football executive)">John Schneider</a></td></tr><tr><th scope="row">Owner</th><td class="fn"><a href="/wiki/Paul_Allen" title="Paul Allen">Paul Allen</a></td></tr><tr><th scope="row">Home field</th><td class="label"><a href="/wiki/CenturyLink_Field" title="CenturyLink Field">CenturyLink Field</a></td></tr><tr><th class="note" colspan="2" style="text-align:center;background: #69BE28; color: #002244; border:2.5px solid background: #69BE28;">Results</th></tr><tr><th scope="row">Record</th><td>13–3</td></tr><tr><th scope="row">Division place</th><td>1st <a href="/wiki/NFC_West" title="NFC West">NFC West</a></td></tr><tr><th scope="row">Playoff finish</th><td><b>Won <a href="/wiki/2013%E2%80%9314_NFL_playoffs" title="2013–14 NFL playoffs">Divisional Playoffs</a></b> (vs. <a href="/wiki/2013_New_Orleans_Saints_season" title="2013 New Orleans Saints season">Saints</a>) 23–15<br/><b>Won <a href="/wiki/2013%E2%80%9314_NFL_playoffs" title="2013–14 NFL playoffs">NFC Championship</a></b> (vs. <a href="/wiki/2013_San_Francisco_49ers_season" title="2013 San Francisco 49ers season">49ers</a>) <a href="/wiki/The_Tip_(American_football)" title="The Tip (American football)">23–17</a><br/><b>Won <a href="/wiki/Super_Bowl_XLVIII" title="Super Bowl XLVIII">Super Bowl XLVIII</a></b> (vs. <a href="/wiki/2013_Denver_Broncos_season" title="2013 Denver Broncos season">Broncos</a>) 43–8</td></tr><tr><th scope="row"><a href="/wiki/2014_Pro_Bowl" title="2014 Pro Bowl">Pro Bowlers</a></th><td><span style="font-size:85%;">Selected but did not participate due to participation in Super Bowl XLVIII:</span><br/>SS <a href="/wiki/Kam_Chancellor" title="Kam Chancellor">Kam Chancellor</a><br/>RB <a href="/wiki/Marshawn_Lynch" title="Marshawn Lynch">Marshawn Lynch</a><br/>CB <a href="/wiki/Richard_Sherman_(American_football)" title="Richard Sherman (American football)">Richard Sherman</a><br/>FS <a class="mw-redirect" href="/wiki/Earl_Thomas_(defensive_back)" title="Earl Thomas (defensive back)">Earl Thomas</a><br/>C <a href="/wiki/Max_Unger" title="Max Unger">Max Unger</a><br/>QB <a href="/wiki/Russell_Wilson" title="Russell Wilson">Russell Wilson</a></td></tr><tr><th scope="row"><a href="/wiki/2013_All-Pro_Team" title="2013 All-Pro Team">AP All-Pros</a></th><td>CB <a href="/wiki/Richard_Sherman_(American_football)" title="Richard Sherman (American football)">Richard Sherman</a> <i>(first team)</i><br/>FS <a class="mw-redirect" href="/wiki/Earl_Thomas_(defensive_back)" title="Earl Thomas (defensive back)">Earl Thomas</a> <i>(first team)</i><br/>SS <a href="/wiki/Kam_Chancellor" title="Kam Chancellor">Kam Chancellor</a> <i>(second team)</i></td></tr><tr><th class="note" colspan="2" style="text-align:center;background: #69BE28; color: #002244; border:2.5px solid background: #69BE28;">Uniform</th></tr><tr><td colspan="2" style="text-align:center"><a class="image" href="/wiki/File:Seattle_seahawks_uniforms_2012-2017.png"><img alt="Seattle seahawks uniforms 2012-2017.png" data-file-height="840" data-file-width="887" decoding="async" height="237" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/53/Seattle_seahawks_uniforms_2012-2017.png/250px-Seattle_seahawks_uniforms_2012-20 ...
# <ul><li>← <a href="/wiki/2012_Seattle_Seahawks_season" title="2012 Seattle Seahawks season">2012</a></li>
# <li><b><a href="/wiki/List_of_Seattle_Seahawks_seasons" title="List of Seattle Seahawks seasons">Seahawks seasons</a></b></li>
# <li><a href="/wiki/2014_Seattle_Seahawks_season" title="2014 Seattle Seahawks season">2014</a> →</li></ul>
# </td></tr></tbody></table>
# <p>The <a href="/wiki/2013_NFL_season" title="2013 NFL season">2013 season</a> was the <a href="/wiki/Seattle_Seahawks" title="Seattle Seahawks">Seattle Seahawks</a>' 38th in the <a href="/wiki/National_Football_League" title="National Football League">National Football League</a> and their fourth under <a href="/wiki/List_of_Seattle_Seahawks_head_coaches" title="List of Seattle Seahawks head coaches">head coach</a> <a href="/wiki/Pete_Carroll" title="Pete Carroll">Pete Carroll</a>. With the Seahawks 10th win only 11 weeks into the season, the team secured double-digit victories in consecutive seasons for the first time in franchise history. Their 13–3 regular season record is tied with the <a href="/wiki/2005_Seattle_Seahawks_season" title="2005 Seattle Seahawks season">2005 season</a> for the best in franchise history. <a href="/wiki/Legion_of_Boom_(Seattle_Seahawks)" title="Legion of Boom (Seattle Seahawks)">Seattle's defense</a> in 2013 is regarded by many to be among the best ever in NFL history.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>
# </p><p>Seattle entered the 2013 season at 17/2 odds to win <a href="/wiki/Super_Bowl_XLVIII" title="Super Bowl XLVIII">Super Bowl XLVIII</a>,<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup> just short of the <a href="/wiki/2013_Denver_Broncos_season" title="2013 Denver Broncos season">Denver Broncos</a> and <a href="/wiki/2013_San_Francisco_49ers_season" title="2013 San Francisco 49ers season">San Francisco 49ers</a> at 6/1. This was despite placing second in the <a href="/wiki/NFC_West" title="NFC West">NFC West</a> and dropping its divisional round game against the <a href="/wiki/2012_Atlanta_Falcons_season" title="2012 Atlanta Falcons season">Atlanta Falcons</a> <a href="/wiki/2012_Seattle_Seahawks_season" title="2012 Seattle Seahawks season">the previous year</a>. The Seahawks were, by power ranking, ranked the strongest team by an <a class="mw-redirect" href="/wiki/NFL.com" title="NFL.com">NFL.com</a> analyst before the season<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup> and by <a href="/wiki/ESPN" title="ESPN">ESPN</a> analysts after the regular season.<sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup> The defense led the league in points allowed (231), yards allowed (4,378), and takeaways (39), the first team to lead all three categories since the <a href="/wiki/1985_Chicago_Bears_season" title="1985 Chicago Bears season">1985 Chicago Bears</a>.<sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[5]</a></sup>
# </p><p>The Seahawks clinched the <a href="/wiki/National_Football_Conference" title="National Football Conference">NFC</a>'s No. 1 seed and homefield advantage throughout the <a href="/wiki/2013%E2%80%9314_NFL_playoffs" title="2013–14 NFL playoffs">playoffs</a> with their 13–3 record. The Seahawks defeated the <a href="/wiki/2013_New_Orleans_Saints_season" title="2013 New Orleans Saints season">New Orleans Saints</a> 23–15 in the Divisional round and the <a href="/wiki/San_Francisco_49ers" title="San Francisco 49ers">San Francisco 49ers</a> 23–17 in the NFC Championship. In <a href="/wiki/Super_Bowl_XLVIII" title="Super Bowl XLVIII">Super Bowl XLVIII</a>, they defeated the <a href="/wiki/Denver_Broncos" title="Denver Broncos">Denver Broncos</a> 43–8 for their first <a href="/wiki/List_of_Super_Bowl_champions" title="List of Super Bowl champions">Super Bowl</a> victory in franchise history.<sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[6]</a></sup>
# </p>
# <style data-mw-deduplicate="TemplateStyles:r886046785">.mw-parser-output .toclimit-2 .toclevel-1 ul,.mw-parser-output .toclimit-3 .toclevel-2 ul,.mw-parser-output .toclimit-4 .toclevel-3 ul,.mw-parser-output .toclimit-5 .toclevel-4 ul,.mw-parser-output .toclimit-6 .toclevel-5 ul,.mw-parser-output .toclimit-7 .toclevel-6 ul{display:none}</style><div class="toclimit-3"><div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#2013_draft_class"><span class="tocnumber">1</span> <span class="toctext">2013 draft class</span></a></li>
# <li class="toclevel-1 tocsection-2"><a href="#Staff"><span class="tocnumber">2</span> <span class="toctext">Staff</span></a></li>
# <li class="toclevel-1 tocsection-3"><a href="#Final_roster"><span class="tocnumber">3</span> <span class="toctext">Final roster</span></a></li>
# <li class="toclevel-1 tocsection-4"><a href="#Schedule"><span class="tocnumber">4</span> <span class="toctext">Schedule</span></a>
# <ul>
# <li class="toclevel-2 tocsection-5"><a href="#Preseason"><span class="tocnumber">4.1</span> <span class="toctext">Preseason</span></a></li>
# <li class="toclevel-2 tocsection-6"><a href="#Regular_season"><span class="tocnumber">4.2</span> <span class="toctext">Regular season</span></a></li>
# <li class="toclevel-2 tocsection-7"><a href="#Postseason"><span class="tocnumber">4.3</span> <span class="toctext">Postseason</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-8"><a href="#Standings"><span class="tocnumber">5</span> <span class="toctext">Standings</span></a>
# <ul>
# <li class="toclevel-2 tocsection-9"><a href="#Division"><span class="tocnumber">5.1</span> <span class="toctext">Division</span></a></li>
# <li class="toclevel-2 tocsection-10"><a href="#Conference"><span class="tocnumber">5.2</span> <span class="toctext">Conference</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-11"><a href="#Game_Summaries"><span class="tocnumber">6</span> <span class="toctext">Game Summaries</span></a>
# <ul>
# <li class="toclevel-2 tocsection-12"><a href="#Preseason_2"><span class="tocnumber">6.1</span> <span class="toctext">Preseason</span></a>
# <ul>
# <li class="toclevel-3 tocsection-13"><a href="#Week_P1:_at_San_Diego_Chargers"><span class="tocnumber">6.1.1</span> <span class="toctext">Week P1: at San Diego Chargers</span></a></li>
# <li class="toclevel-3 tocsection-14"><a href="#Week_P2:_vs._Denver_Broncos"><span class="tocnumber">6.1.2</span> <span class="toctext">Week P2: vs. Denver Broncos</span></a></li>
# <li class="toclevel-3 tocsection-15"><a href="#Week_P3:_at_Green_Bay_Packers"><span class="tocnumber">6.1.3</span> <span class="toctext">Week P3: at Green Bay Packers</span></a></li>
# <li class="toclevel-3 tocsection-16"><a href="#Week_P4:_vs._Oakland_Raiders"><span class="tocnumber">6.1.4</span> <span class="toctext">Week P4: vs. Oakland Raiders</span></a></li>
# </ul>
# </li>
# <li class="toclevel-2 tocsection-17"><a href="#Regular_Season_2"><span class="tocnumber">6.2</span> <span class="toctext">Regular Season</span></a>
# <ul>
# <li class="toclevel-3 tocsection-18"><a href="#Week_1:_at_Carolina_Panthers"><span class="tocnumber">6.2.1</span> <span class="toctext">Week 1: at Carolina Panthers</span></a></li>
# <li class="toclevel-3 tocsection-19"><a href="#Week_2:_vs._San_Francisco_49ers"><span class="tocnumber">6.2.2</span> <span class="toctext">Week 2: vs. San Francisco 49ers</span></a></li>
# <li class="toclevel-3 tocsection-20"><a href="#Week_3:_vs._Jacksonville_Jaguars"><span class="tocnumber">6.2.3</span> <span class="toctext">Week 3: vs. Jacksonville Jaguars</span></a></li>
# <li class="toclevel-3 tocsection-21"><a href="#Week_4:_at_Houston_Texans"><span class="tocnumber">6.2.4</span> <span class="toctext">Week 4: at Houston Texans</span></a></li>
# <li class="toclevel-3 tocsection-22"><a href="#Week_5:_at_Indianapolis_Colts"><span class="tocnumber">6.2.5</span> <span class="toctext">Week 5: at Indianapolis Colts</span></a></li>
# <li class="toclevel-3 tocsection-23"><a href="#Week_6:_vs._Tennessee_Titans"><span class="tocnumber">6.2.6</span> <span class="toctext">Week 6: vs. Tennessee Titans</span></a></li>
# <li class="toclevel-3 tocsection-24"><a href="#Week_7:_at_Arizona_Cardinals"><span class="tocnumber">6.2.7</span> <span class="toctext">Week 7: at Arizona Cardinals</span></a></li>
# <li class="toclevel-3 tocsection-25"><a href="#Week_8:_at_St._Louis_Rams"><span class="tocnumber">6.2.8</span> <span class="toctext">Week 8: at St. Louis Rams</span></a></li>
# <li class="toclevel-3 tocsection-26"><a href="#Week_9:_vs._Tampa_Bay_Buccaneers"><span class="tocnumber">6.2.9</span> <span class="toctext">Week 9: vs. Tampa Bay Buccaneers</span></a></li>
# <li class="toclevel-3 tocsection-27"><a href="#Week_10:_at_Atlanta_Falcons"><span class="tocnumber">6.2.10</span> <span class="toctext">Week 10: at Atlanta Falcons</span></a></li>
# <li class="toclevel-3 tocsection-28"><a href="#Week_11:_vs._Minnesota_Vikings"><span class="tocnumber">6.2.11</span> <span class="toctext">Week 11: vs. Minnesota Vikings</span></a></li>
# <li class="toclevel-3 tocsection-29"><a href="#Week_13:_vs._New_Orleans_Saints"><span class="tocnumber">6.2.12</span> <span class="toctext">Week 13: vs. New Orleans Saints</span></a></li>
# <li class="toclevel-3 tocsection-30"><a href="#Week_14:_at_San_Francisco_49ers"><span class="tocnumber">6.2.13</span> <span class="toctext">Week 14: at San Francisco 49ers</span></a></li>
# <li class="toclevel-3 tocsection-31"><a href="#Week_15:_at_New_York_Giants"><span class="tocnumber">6.2.14</span> <span class="toctext">Week 15: at New York Giants</span></a></li>
# <li class="toclevel-3 tocsection-32"><a href="#Week_16:_vs._Arizona_Cardinals"><span class="tocnumber">6.2.15</span> <span class="toctext">Week 16: vs. Arizona Cardinals</span></a></li>
# <li class="toclevel-3 tocsection-33"><a href="#Week_17:_vs._St._Louis_Rams"><span class="tocnumber">6.2.16</span> <span class="toctext">Week 17: vs. St. Louis Rams</span></a></li>
# </ul>
# </li>
# <li class="toclevel-2 tocsection-34"><a href="#Postseason_2"><span class="tocnumber">6.3</span> <span class="toctext">Postseason</span></a>
# <ul>
# <li class="toclevel-3 tocsection-35"><a href="#NFC_Divisional_Playoff:_vs._#6_New_Orleans_Saints"><span class="tocnumber">6.3.1</span> <span class="toctext">NFC Divisional Playoff: vs. #6 New Orleans Saints</span></a></li>
# <li class="toclevel-3 tocsection-36"><a href="#NFC_Championship_Game:_vs._#5_San_Francisco_49ers"><span class="tocnumber">6.3.2</span> <span class="toctext">NFC Championship Game: vs. #5 San Francisco 49ers</span></a></li>
# <li class="toclevel-3 tocsection-37"><a href="#Super_Bowl_XLVIII:_vs._#A1_Denver_Broncos"><span class="tocnumber">6.3.3</span> <span class="toctext">Super Bowl XLVIII: vs. #A1 Denver Broncos</span></a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-38"><a href="#References"><span class="tocnumber">7</span> <span class="toctext">References</span></a></li>
# <li class="toclevel-1 tocsection-39"><a href="#External_links"><span class="tocnumber">8</span> <span class="toctext">External links</span></a></li>
# </ul>
# </div>
# </div>
# <h2><span class="mw-headline" id="2013_draft_class">2013 draft class</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=2013_Seattle_Seahawks_season&amp;action=edit&amp;section=1" title="Edit section: 2013 draft class">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="hatnote navigation-not-searchable" role="note">Main article: <a href="/wiki/2013_NFL_Draft" title="2013 NFL Draft">2013 NFL Draft</a></div>
# <table class="wikitable" style="font-size: 95%; text-align: center;">
#
# <tbody><tr>
# <th>Round</th>
# <th>Selection</th>
# <th>Player</th>
# <th>Position</th>
# <th>College
# </th></tr>
# <tr>
# <th>2</th>
# <th>62<sup class="reference plainlinks nourlexpansion" id="ref_Ravens/Lions_trade"><a href="#endnote_Ravens/Lions_trade">[b]</a></sup>
# </th>
# <td><a href="/wiki/Christine_Michael" title="Christine Michael">Christine Michael</a></td>
# <td><a href="/wiki/Running_back" title="Running back">RB</a></td>
# <td><a href="/wiki/Texas_A%26M_Aggies_football" title="Texas A&amp;M Aggies football">Texas A&amp;M</a>
# </td></tr>
# <tr>
# <th>3</th>
# <th>87
# </th>
# <td><a href="/wiki/Jordan_Hill_(American_football)" title="Jordan Hill (American football)">Jordan Hill</a></td>
# <td><a href="/wiki/Defensive_tackle" title="Defensive tackle">DT</a></td>
# <td><a href="/wiki/Penn_State_Nittany_Lions_football" title="Penn State Nittany Lions football">Penn State</a>
# </td></tr>
# <tr>
# <th>4</th>
# <th>123
# </th>
# <td><a href="/wiki/Chris_Harper_(wide_receiver,_born_1989)" title="Chris Harper (wide receiver, born 1989)">Chris Harper</a></td>
# <td><a href="/wiki/Wide_receiver" title="Wide receiver">WR</a></td>
# <td><a href="/wiki/Kansas_State_Wildcats_football" title="Kansas State Wildcats football">Kansas State</a>
# </td></tr>
# <tr>
# <th rowspan="3">5</th>
# <th>137<sup class="reference plainlinks nourlexpansion" id="ref_Ravens/Lions_trade"><a href="#endnote_Ravens/Lions_trade">[b]</a></sup>
# </th>
# <td><a href="/wiki/Jesse_Williams_(American_football)" title="Jesse Williams (American football)">Jesse Williams</a></td>
# <td>DT</td>
# <td><a href="/wiki/Alabama_Crimson_Tide_football" title="Alabama Crimson Tide football">Alabama</a>
# </td></tr>
# <tr>
# <th>138<sup class="reference plainlinks nourlexpansion" id="ref_Raiders_trade"><a href="#endnote_Raiders_trade">[c]</a></sup>
# </th>
# <td><a href="/wiki/Tharold_Simon" title="Tharold Simon">Tharold Simon</a></td>
# <td><a href="/wiki/Cornerback" title="Cornerback">CB</a></td>
# <td><a href="/wiki/LSU_Tigers_football" title="LSU Tigers football">LSU</a>
# </td></tr>
# <tr>
# <th>158
# </th>
# <td><a href="/wiki/Luke_Willson" title="Luke Willson">Luke Willson</a></td>
# <td><a class="mw-redirect" href="/wiki/Tight_End" title="Tight End">TE</a></td>
# <td><a href="/wiki/Rice_Owls_football" title="Rice Owls football">Rice</a>
# </td></tr>
# <tr>
# <th>6<sup class="reference plainlinks nourlexpansion" id="ref_Ravens/Lions_trade"><a href="#endnote_Ravens/Lions_trade">[b]</a></sup></th>
# <th>194
# </th>
# <td><a href="/wiki/Spencer_Ware" title="Spencer Ware">Spencer Ware</a></td>
# <td>RB</td>
# <td>LSU
# </td></tr>
# <tr>
# <th rowspan="4">7<sup class="reference plainlinks nourlexpansion" id="ref_Vikings/Bills_trade"><a href="#endnote_Vikings/Bills_trade">[a]</a></sup></th>
# <th>220<sup class="reference plainlinks nourlexpansion" id="ref_Saints_trade"><a href="#endnote_Saints_trade">[d]</a></sup>
# </th>
# <td><a href="/wiki/Ryan_Seymour" title="Ryan Seymour">Ryan Seymour</a></td>
# <td><a class="mw-redirect" href="/wiki/Guard_(American_and_Canadian_football)" title="Guard (American and Canadian football)">G</a></td>
# <td><a href="/wiki/Vanderbilt_Commodores_football" title="Vanderbilt Commodores football">Vanderbilt</a>
# </td></tr>
# <tr>
# <th>231
# </th>
# <td><a href="/wiki/Ty_Powell" title="Ty Powell">Ty Powell</a></td>
# <td><a href="/wiki/Linebacker" title="Linebacker">LB</a></td>
# <td><a href="/wiki/Harding_Bisons_football" title="Harding Bisons football">Harding</a>
# </td></tr>
# <tr>
# <th>241<sup class="reference plainlinks nourlexpansion" id="ref_Compensatory"><a href="#endnote_Compensatory">[e]</a></sup>
# </th>
# <td><a class="mw-redirect" href="/wiki/Jared_Smith_(American_football)" title="Jared Smith (American football)">Jared Smith</a></td>
# <td>DT</td>
# <td><a href="/wiki/New_Hampshire_Wildcats_football" title="New Hampshire Wildcats football">New Hampshire</a>
# </td></tr>
# <tr>
# <th>242<sup class="reference plainlinks nourlexpansion" id="ref_Compensatory"><a href="#endnote_Compensatory">[e]</a></sup>
# </th>
# <td><a href="/wiki/Michael_Bowie" title="Michael Bowie">Michael Bowie</a></td>
# <td><a class="mw-redirect" href="/wiki/Tackle_(American_and_Canadian_football)" title="Tackle (American and Canadian football)">OT</a></td>
# <td><a href="/wiki/Northeastern_State_RiverHawks_football" title="Northeastern State RiverHawks football">Northeastern State</a>
# </td></tr></tbody></table>
# <p><b>Notes</b>
# </p>
# <dl><dd><sup><span class="citation wikicite" id="endnote_Vikings/Bills_trade"><b><a href="#ref_Vikings/Bills_trade">^[a]</a></b></span> </sup> The Seahawks traded their first-round selection (No. 25 overall), one of their seventh-round selections (No. 214 overall; previously acquired in a trade that sent <a href="/wiki/Quarterback" title="Quarterback">quarterback</a> <a href="/wiki/Tarvaris_Jackson" title="Tarvaris Jackson">Tarvaris Jackson</a> to the <a href="/wiki/Buffalo_Bills" title="Buffalo Bills">Buffalo Bills</a>) and a conditional <a href="/wiki/2014_NFL_Draft" title="2014 NFL Draft">2014</a> selection to the <a href="/wiki/Minnesota_Vikings" title="Minnesota Vikings">Minnesota Vikings</a> in exchange for <a href="/wiki/Wide_receiver" title="Wide receiver">wide receiver</a> <a href="/wiki/Percy_Harvin" title="Percy Harvin">Percy Harvin</a>.</dd>
# <dd><sup><span class="citation wikicite" id="endnote_Ravens/Lions_trade"><b><a href="#ref_Ravens/Lions_trade">^[b]</a></b></span> </sup> The Seahawks traded their second-round selection (No. 56 overall) to the Baltimore Ravens in exchange for the Ravens' second-, fifth- and sixth- round selections — Nos. 62, 165 and 199 overall. The latter two selections were traded to the <a href="/wiki/Detroit_Lions" title="Detroit Lions">Detroit Lions</a> in exchange for the Lions' fifth-round selection (No. 137 overall).</dd>
# <dd><sup><span class="citation wikicite" id="endnote_Raiders_trade"><b><a href="#ref_Raiders_trade">^[c]</a></b></span> </sup> The Seahawks acquired this fifth-round selection as part of a trade that sent linebacker <a href="/wiki/Aaron_Curry_(American_football)" title="Aaron Curry (American football)">Aaron Curry</a> to the <a class="mw-redirect" href="/wiki/Oakland_Raiders" title="Oakland Raiders">Oakland Raiders</a>.</dd>
# <dd><sup><span class="citation wikicite" id="endnote_Saints_trade"><b><a href="#ref_Saints_trade">^[d]</a></b></span> </sup> The Seahawks acquired this seventh-round selection in a trade that sent <a href="/wiki/Linebacker" title="Linebacker">linebacker</a> <a href="/wiki/Barrett_Ruud" title="Barrett Ruud">Barrett Ruud</a> to the <a href="/wiki/New_Orleans_Saints" title="New Orleans Saints">New Orleans Saints</a>.</dd>
# <dd><sup><span class="citation wikicite" id="endnote_Compensatory"><b><a href="#ref_Compensatory">^[e]</a></b></span> </sup> <a href="/wiki/National_Football_League_Draft#Compensatory_picks" title="National Football League Draft">Compensatory selection</a>.</dd></dl>
# <h2><span class="mw-headline" id="Staff">Staff</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=2013_Seattle_Seahawks_season&amp;action=edit&amp;section=2" title="Edit section: Staff">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <table class="toccolours" style="font-size: 95%;">
# <caption style="background: #002244; color: #FFFFFF; border: 2px solid  #69BE28"><b>2013 Seattle Seahawks staff</b>
# </caption>
# <tbody><tr>
# <td colspan="7" style="text-align:right;">
# </td></tr>
# <tr>
# <td style="vertical-align:top;">
# </td>
# <td style="font-size: 95%;vertical-align:top;"><b>Front office</b>
# <ul><li>Chairman – <a href="/wiki/Paul_Allen" title="Paul Allen">Paul Allen</a></li>
# <li>President – <a href="/wiki/Peter_McLoughlin" title="Peter McLoughlin">Peter McLoughlin</a></li>
# <li>Executive Vice President/General Manager – <a href="/wiki/John_Schneider_(American_football_executive)" title="John Schneider (American football executive)">John Schneider</a></li>
# <li>Senior Personnel Executive – <a href="/wiki/Scot_McCloughan" title="Scot McCloughan">Scot McCloughan</a></li>
# <li>Senior Vice President of Football Administration – Matt Thomas</li>
# <li>Director of Pro Personnel – Trent Kirchner</li>
# <li>Director of College Scouting – Scott Fitterer</li>
# <li>Assistant Director of Pro Personnel – <a href="/wiki/Dan_Morgan" title="Dan Morgan">Dan Morgan</a></li></ul>
# <p><b>Head coaches</b>
# </p>
# <ul><li>Executive Vice President of Football Operations/Head Coach – <a href="/wiki/Pete_Carroll" title="Pete Carroll">Pete Carroll</a></li>
# <li>Assistant Head Coach/Offensive Line – <a href="/wiki/Tom_Cable" title="Tom Cable">Tom Cable</a></li></ul>
# <p><b>Offensive coaches</b>
# </p>
# <ul><li>Offensive Coordinator – <a href="/wiki/Darrell_Bevell" title="Darrell Bevell">Darrell Bevell</a></li>
# <li>Quarterbacks – <a href="/wiki/Carl_Smith_(American_football)" title="Carl Smith (American football)">Carl Smith</a></li>
# <li>Running Backs – <a href="/wiki/Sherman_Smith" title="Sherman Smith">Sherman Smith</a></li>
# <li>Wide Receivers – <a href="/wiki/Kippy_Brown" title="Kippy Brown">Kippy Brown</a></li>
# <li>Tight Ends – <a href="/wiki/Pat_McPherson" title="Pat McPherson">Pat McPherson</a></li>
# <li>Assistant Offensive Line – <a href="/wiki/Pat_Ruel" title="Pat Ruel">Pat Ruel</a></li>
# <li>Offensive Assistant – <a class="new" href="/w/index.php?title=Nate_Carroll&amp;action=edit&amp;redlink=1" title="Nate Carroll (page does not exist)">Nate Carroll</a></li>
# <li>Offensive Quality Control/Assistant Quarterbacks – <a href="/wiki/Dave_Canales" title="Dave Canales">Dave Canales</a></li>
# <li>Quality Control/Offense – <a class="new" href="/w/index.php?title=Keith_Carter_(American_football)&amp;action=edit&amp;redlink=1" title="Keith Carter (American football) (page does not exist)">Keith Carter</a></li></ul>
# </td>
# <td width="35">
# </td>
# <td style="vertical-align:top;">
# </td>
# <td style="font-size: 95%;vertical-align:top;"><b>Defensive coaches</b>
# <ul><li>Defensive Coordinator – <a href="/wiki/Dan_Quinn_(American_football)" title="Dan Quinn (American football)">Dan Quinn</a></li>
# <li>Pass Game Coordinator – <a href="/wiki/Rocky_Seto" title="Rocky Seto">Rocky Seto</a></li>
# <li>Defensive Line – <a href="/wiki/Travis_Jones" title="Travis Jones">Travis Jones</a></li>
# <li>Linebackers – <a class="mw-redirect" href="/wiki/Ken_Norton,_Jr." title="Ken Norton, Jr.">Ken Norton, Jr.</a></li>
# <li>Defensive Backs – <a href="/wiki/Kris_Richard" title="Kris Richard">Kris Richard</a></li>
# <li>Defensive Assistant – <a href="/wiki/Marquand_Manuel" title="Marquand Manuel">Marquand Manuel</a></li>
# <li>Quality Control/Defense – <a href="/wiki/Robert_Saleh" title="Robert Saleh">Robert Saleh</a></li></ul>
# <p><b>Special teams coaches</b>
# </p>
# <ul><li>Special Teams Coordinator – <a href="/wiki/Brian_Schneider" title="Brian Schneider">Brian Schneider</a></li>
# <li>Assistant Special Teams – <a href="/wiki/Nick_Sorensen" title="Nick Sorensen">Nick Sorensen</a></li></ul>
# <p><b>Strength and conditioning</b>
# </p>
# <ul><li>Head Strength and Conditioning – Chris Carlisle</li>
# <li>Assistant Strength and Conditioning – <a class="new" href="/w/index.php?title=Mondray_Gee&amp;action=edit&amp;redlink=1" title="Mondray Gee (page does not exist)">Mondray Gee</a></li>
# <li>Assistant Strength and Conditioning – Jamie Yancher</li></ul>
# </td></tr></tbody></table>
# <h2><span class="mw-headline" id="Final_roster">Final roster</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=2013_Seattle_Seahawks_season&amp;action=edit&amp;section=3" title="Edit section: Final roster">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <table class="toccolours" style="font-size: 95%;">
# <caption style="background: #002244; color: #FFFFFF; border: 2px solid  #69BE28"><b>2013 Seattle Seahawks final roster</b>
# </caption>
# <tbody><tr>
# <td colspan="10" style="text-align:right;">
# </td></tr>
# <tr>
# <td style="vertical-align:top;">
# </td>
# <td style="font-size: 95%;vertical-align:top;"><b>Quarterbacks</b>
# <ul><li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"> 7</span> <a href="/wiki/Tarvaris_Jackson" title="Tarvaris Jackson">Tarvaris Jackson</a></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"> <b>3</b></span><b> <a href="/wiki/Russell_Wilson" title="Russell Wilson">Russell Wilson</a>  </b> *</li></ul>
# <p><b>Running backs</b>
# </p>
# <ul><li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">40</span> <a href="/wiki/Derrick_Coleman_(American_football)" title="Derrick Coleman (American football)">Derrick Coleman</a> FB</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>24</b></span><b> <a href="/wiki/Marshawn_Lynch" title="Marshawn Lynch">Marshawn Lynch</a>  </b> *</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">33</span> <i><a href="/wiki/Christine_Michael" title="Christine Michael">Christine Michael</a></i></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>26</b></span><b> <a href="/wiki/Michael_Robinson_(fullback)" title="Michael Robinson (fullback)">Michael Robinson</a> FB </b></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">22</span> <a href="/wiki/Robert_Turbin" title="Robert Turbin">Robert Turbin</a></li></ul>
# <p><b>Wide receivers</b>
# </p>
# <ul><li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>89</b></span><b> <a class="mw-redirect" href="/wiki/Doug_Baldwin_(American_football)" title="Doug Baldwin (American football)">Doug Baldwin</a>  </b></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">11</span> <a href="/wiki/Percy_Harvin" title="Percy Harvin">Percy Harvin</a></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">15</span> <a href="/wiki/Jermaine_Kearse" title="Jermaine Kearse">Jermaine Kearse</a></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">83</span> <a href="/wiki/Ricardo_Lockette" title="Ricardo Lockette">Ricardo Lockette</a></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">19</span> <a href="/wiki/Bryan_Walters" title="Bryan Walters">Bryan Walters</a></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>81</b></span><b> <a href="/wiki/Golden_Tate" title="Golden Tate">Golden Tate</a>  </b></li></ul>
# <p><b>Tight ends</b>
# </p>
# <ul><li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">87</span> <a href="/wiki/Kellen_Davis" title="Kellen Davis">Kellen Davis</a></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>86</b></span><b> <a href="/wiki/Zach_Miller_(tight_end,_born_1985)" title="Zach Miller (tight end, born 1985)">Zach Miller</a>  </b></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">82</span> <i><a href="/wiki/Luke_Willson" title="Luke Willson">Luke Willson</a></i></li></ul>
# </td>
# <td style="width: 25px;">
# </td>
# <td style="font-size: 95%;vertical-align:top;"><b>Offensive linemen</b>
# <ul><li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">78</span> <i><a href="/wiki/Alvin_Bailey" title="Alvin Bailey">Alvin Bailey</a></i> G</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">73</span> <i><a href="/wiki/Michael_Bowie" title="Michael Bowie">Michael Bowie</a></i> T</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>77</b></span><b> <a href="/wiki/James_Carpenter_(American_football)" title="James Carpenter (American football)">James Carpenter</a> G </b></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>68</b></span><b> <a href="/wiki/Breno_Giacomini" title="Breno Giacomini">Breno Giacomini</a> T </b></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">74</span> <i><a href="/wiki/Caylin_Hauptmann" title="Caylin Hauptmann">Caylin Hauptmann</a></i> T</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">61</span> <a href="/wiki/Lemuel_Jeanpierre" title="Lemuel Jeanpierre">Lemuel Jeanpierre</a> C</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>67</b></span><b> <a href="/wiki/Paul_McQuistan" title="Paul McQuistan">Paul McQuistan</a> T </b></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">76</span> <a href="/wiki/Russell_Okung" title="Russell Okung">Russell Okung</a> T</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>64</b></span><b> <a href="/wiki/J._R._Sweezy" title="J. R. Sweezy">J. R. Sweezy</a> G </b></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>60</b></span><b> <a href="/wiki/Max_Unger" title="Max Unger">Max Unger</a> C </b> *</li></ul>
# <p><b>Defensive linemen</b>
# </p>
# <ul><li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">56</span> <a href="/wiki/Cliff_Avril" title="Cliff Avril">Cliff Avril</a> DE</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">72</span> <a href="/wiki/Michael_Bennett_(defensive_lineman,_born_1985)" title="Michael Bennett (defensive lineman, born 1985)">Michael Bennett</a> DE</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>79</b></span><b> <a href="/wiki/Red_Bryant" title="Red Bryant">Red Bryant</a> DE </b></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>91</b></span><b> <a href="/wiki/Chris_Clemons_(defensive_end)" title="Chris Clemons (defensive end)">Chris Clemons</a> DE </b></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">97</span> <i><a href="/wiki/Jordan_Hill_(American_football)" title="Jordan Hill (American football)">Jordan Hill</a></i> DT</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">95</span> <i><a href="/wiki/Benson_Mayowa" title="Benson Mayowa">Benson Mayowa</a></i> DE</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>99</b></span><b> <a href="/wiki/Tony_McDaniel" title="Tony McDaniel">Tony McDaniel</a> DT </b></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">69</span> <a href="/wiki/Clinton_McDonald" title="Clinton McDonald">Clinton McDonald</a> DT</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>92</b></span><b> <a href="/wiki/Brandon_Mebane" title="Brandon Mebane">Brandon Mebane</a> DT </b></li></ul>
# </td>
# <td style="width: 25px;">
# </td>
# <td style="font-size: 95%;vertical-align:top;"><b>Linebackers</b>
# <ul><li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">55</span> <a href="/wiki/Heath_Farwell" title="Heath Farwell">Heath Farwell</a> MLB</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>51</b></span><b> <a class="mw-redirect" href="/wiki/Bruce_Irvin_(American_football)" title="Bruce Irvin (American football)">Bruce Irvin</a> OLB </b></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">57</span> <a href="/wiki/Mike_Morgan_(linebacker,_born_1988)" title="Mike Morgan (linebacker, born 1988)">Mike Morgan</a> OLB</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">93</span> <a href="/wiki/O%27Brien_Schofield" title="O'Brien Schofield">O'Brien Schofield</a> LB</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">53</span> <a href="/wiki/Malcolm_Smith_(American_football)" title="Malcolm Smith (American football)">Malcolm Smith</a> OLB</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>54</b></span><b> <a href="/wiki/Bobby_Wagner" title="Bobby Wagner">Bobby Wagner</a> MLB </b></li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>50</b></span><b> <a href="/wiki/K._J._Wright" title="K. J. Wright">K. J. Wright</a> OLB </b></li></ul>
# <p><b>Defensive backs</b>
# </p>
# <ul><li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>31</b></span><b> <a href="/wiki/Kam_Chancellor" title="Kam Chancellor">Kam Chancellor</a> SS </b> *</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">20</span> <a class="mw-redirect" href="/wiki/Jeremy_Lane_(American_football)" title="Jeremy Lane (American football)">Jeremy Lane</a> CB</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">42</span> <a href="/wiki/Chris_Maragos" title="Chris Maragos">Chris Maragos</a> FS</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">41</span> <a href="/wiki/Byron_Maxwell" title="Byron Maxwell">Byron Maxwell</a> CB</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">35</span> <a href="/wiki/DeShawn_Shead" title="DeShawn Shead">DeShawn Shead</a> SS</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>25</b></span><b> <a href="/wiki/Richard_Sherman_(American_football)" title="Richard Sherman (American football)">Richard Sherman</a> CB </b> *</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>29</b></span><b> <a class="mw-redirect" href="/wiki/Earl_Thomas_(defensive_back)" title="Earl Thomas (defensive back)">Earl Thomas</a> FS </b> *</li>
# <li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;">28</span> <a href="/wiki/Walter_Thurmond" title="Walter Thurmond">Walter Thurmond</a> CB</li></ul>
# <p><b>Special teams</b>
# </p>
# ...
# 	<h3 id="p-namespaces-label">
# 		<span>Namespaces</span>
# 	</h3>
# 	<!-- Please do not use the .body class, it is deprecated. -->
# 	<div class="body vector-menu-content">
# 		<!-- Please do not use the .menu class, it is deprecated. -->
# 		<ul class="vector-menu-content-list"><li class="selected" id="ca-nstab-main"><a accesskey="c" href="/wiki/2013_Seattle_Seahawks_season" title="View the content page [c]">Article</a></li><li id="ca-talk"><a accesskey="t" href="/wiki/Talk:2013_Seattle_Seahawks_season" rel="discussion" title="Discuss improvements to the content page [t]">Talk</a></li></ul>
#
# 	</div>
# </nav>
#
#
# 			<!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-variants-label" class="vector-menu-empty emptyPortlet vector-menu vector-menu-dropdown vectorMenu" id="p-variants" role="navigation">
# 	<input aria-labelledby="p-variants-label" class="vector-menu-checkbox vectorMenuCheckbox" type="checkbox"/>
# 	<h3 id="p-variants-label">
# 		<span>Variants</span>
# 	</h3>
# 	<!-- Please do not use the .body class, it is deprecated. -->
# 	<div class="body vector-menu-content">
# 		<!-- Please do not use the .menu class, it is deprecated. -->
# 		<ul class="menu vector-menu-content-list"></ul>
#
# 	</div>
# </nav>
#
#
# 		</div>
# 		<div id="right-navigation">
# 			<!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-views-label" class="vector-menu vector-menu-tabs vectorTabs" id="p-views" role="navigation">
# 	<h3 id="p-views-label">
# 		<span>Views</span>
# 	</h3>
# 	<!-- Please do not use the .body class, it is deprecated. -->
# 	<div class="body vector-menu-content">
# 		<!-- Please do not use the .menu class, it is deprecated. -->
# 		<ul class="vector-menu-content-list"><li class="collapsible selected" id="ca-view"><a href="/wiki/2013_Seattle_Seahawks_season">Read</a></li><li class="collapsible" id="ca-edit"><a accesskey="e" href="/w/index.php?title=2013_Seattle_Seahawks_season&amp;action=edit" title="Edit this page [e]">Edit</a></li><li class="collapsible" id="ca-history"><a accesskey="h" href="/w/index.php?title=2013_Seattle_Seahawks_season&amp;action=history" title="Past revisions of this page [h]">View history</a></li></ul>
#
# 	</div>
# </nav>
#
#
# 			<!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-cactions-label" class="vector-menu-empty emptyPortlet vector-menu vector-menu-dropdown vectorMenu" id="p-cactions" role="navigation">
# 	<input aria-labelledby="p-cactions-label" class="vector-menu-checkbox vectorMenuCheckbox" type="checkbox"/>
# 	<h3 id="p-cactions-label">
# 		<span>More</span>
# 	</h3>
# 	<!-- Please do not use the .body class, it is deprecated. -->
# 	<div class="body vector-menu-content">
# 		<!-- Please do not use the .menu class, it is deprecated. -->
# 		<ul class="menu vector-menu-content-list"></ul>
#
# 	</div>
# </nav>
#
#
# 			<div id="p-search" role="search">
# 	<h3>
# 		<label for="searchInput">Search</label>
# 	</h3>
# 	<form action="/w/index.php" id="searchform">
# 		<div id="simpleSearch">
# 			<input accesskey="f" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
# 			<input name="title" type="hidden" value="Special:Search"/>
# 			<input class="searchButton mw-fallbackSearchButton" id="mw-searchButton" name="fulltext" title="Search Wikipedia for this text" type="submit" value="Search"/>
# 			<input class="searchButton" id="searchButton" name="go" title="Go to a page with this exact name if it exists" type="submit" value="Go"/>
# 		</div>
# 	</form>
# </div>
#
# 		</div>
# 	</div>
#
# <div id="mw-panel">
# 	<div id="p-logo" role="banner">
# 		<a class="mw-wiki-logo" href="/wiki/Main_Page" title="Visit the main page"></a>
# 	</div>
# 	<!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-navigation-label" class="vector-menu vector-menu-portal portal portal-first" id="p-navigation" role="navigation">
# 	<h3 id="p-navigation-label">
# 		<span>Navigation</span>
# 	</h3>
# 	<!-- Please do not use the .body class, it is deprecated. -->
# 	<div class="body vector-menu-content">
# 		<!-- Please do not use the .menu class, it is deprecated. -->
# 		<ul class="vector-menu-content-list"><li id="n-mainpage-description"><a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]">Main page</a></li><li id="n-contents"><a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li><li id="n-randompage"><a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]">Random article</a></li><li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works">About Wikipedia</a></li><li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact us</a></li><li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation">Donate</a></li><li id="n-shoplink"><a href="//shop.wikimedia.org" title="Visit the Wikipedia store">Wikipedia store</a></li></ul>
#
# 	</div>
# </nav>
#
#
# 	<!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-interaction-label" class="vector-menu vector-menu-portal portal" id="p-interaction" role="navigation">
# 	<h3 id="p-interaction-label">
# 		<span>Contribute</span>
# 	</h3>
# 	<!-- Please do not use the .body class, it is deprecated. -->
# 	<div class="body vector-menu-content">
# 		<!-- Please do not use the .menu class, it is deprecated. -->
# 		<ul class="vector-menu-content-list"><li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li><li id="n-recentchanges"><a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]">Recent changes</a></li><li id="n-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Add images or other media for use on Wikipedia">Upload file</a></li></ul>
#
# 	</div>
# </nav>
#
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-tb-label" class="vector-menu vector-menu-portal portal" id="p-tb" role="navigation">
# 	<h3 id="p-tb-label">
# 		<span>Tools</span>
# 	</h3>
# 	<!-- Please do not use the .body class, it is deprecated. -->
# 	<div class="body vector-menu-content">
# 		<!-- Please do not use the .menu class, it is deprecated. -->
# 		<ul class="vector-menu-content-list"><li id="t-whatlinkshere"><a accesskey="j" href="/wiki/Special:WhatLinksHere/2013_Seattle_Seahawks_season" title="List of all English Wikipedia pages containing links to this page [j]">What links here</a></li><li id="t-recentchangeslinked"><a accesskey="k" href="/wiki/Special:RecentChangesLinked/2013_Seattle_Seahawks_season" rel="nofollow" title="Recent changes in pages linked from this page [k]">Related changes</a></li><li id="t-upload"><a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]">Upload file</a></li><li id="t-specialpages"><a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=2013_Seattle_Seahawks_season&amp;oldid=959355204" title="Permanent link to this revision of this page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=2013_Seattle_Seahawks_season&amp;action=info" title="More information about this page">Page information</a></li><li id="t-wikibase"><a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q2657605" title="Structured data on this page hosted by Wikidata [g]">Wikidata item</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=2013_Seattle_Seahawks_season&amp;id=959355204&amp;wpFormIdentifier=titleform" title="Information on how to cite this page">Cite this page</a></li></ul>
#
# 	</div>
# </nav>
#
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-lang-label" class="vector-menu vector-menu-portal portal" id="p-lang" role="navigation">
# 	<h3 id="p-lang-label">
# 		<span>Languages</span>
# 	</h3>
# 	<!-- Please do not use the .body class, it is deprecated. -->
# 	<div class="body vector-menu-content">
# 		<!-- Please do not use the .menu class, it is deprecated. -->
# 		<ul class="vector-menu-content-list"><li class="interlanguage-link interwiki-it"><a class="interlanguage-link-target" href="https://it.wikipedia.org/wiki/Seattle_Seahawks_2013" hreflang="it" lang="it" title="Seattle Seahawks 2013 – Italian">Italiano</a></li></ul>
# 		<div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q2657605#sitelinks-wikipedia" title="Edit interlanguage links">Edit links</a></span></div>
# 	</div>
# </nav>
#
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-wikibase-otherprojects-label" class="vector-menu vector-menu-portal portal" id="p-wikibase-otherprojects" role="navigation">
# 	<h3 id="p-wikibase-otherprojects-label">
# 		<span>In other projects</span>
# 	</h3>
# 	<!-- Please do not use the .body class, it is deprecated. -->
# 	<div class="body vector-menu-content">
# 		<!-- Please do not use the .menu class, it is deprecated. -->
# 		<ul class="vector-menu-content-list"><li class="wb-otherproject-link wb-otherproject-commons"><a href="https://commons.wikimedia.org/wiki/Category:2013_Seattle_Seahawks_season" hreflang="en">Wikimedia Commons</a></li></ul>
#
# 	</div>
# </nav>
#
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-coll-print_export-label" class="vector-menu vector-menu-portal portal" id="p-coll-print_export" role="navigation">
# 	<h3 id="p-coll-print_export-label">
# 		<span>Print/export</span>
# 	</h3>
# 	<!-- Please do not use the .body class, it is deprecated. -->
# 	<div class="body vector-menu-content">
# 		<!-- Please do not use the .menu class, it is deprecated. -->
# 		<ul class="vector-menu-content-list"><li id="coll-download-as-rl"><a href="/w/index.php?title=Special:ElectronPdf&amp;page=2013+Seattle+Seahawks+season&amp;action=show-download-screen" title="Download this page as a PDF file">Download as PDF</a></li><li id="t-print"><a accesskey="p" href="/w/index.php?title=2013_Seattle_Seahawks_season&amp;printable=yes" title="Printable version of this page [p]">Printable version</a></li></ul>
#
# 	</div>
# </nav>
#
#
# </div>
#
# </div>
#
# <footer class="mw-footer" id="footer" role="contentinfo">
# 	<ul id="footer-info">
# 		<li id="footer-info-lastmod"> This page was last edited on 28 May 2020, at 11:17<span class="anonymous-show"> (UTC)</span>.</li>
# 		<li id="footer-info-copyright">Text is available under the <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">Creative Commons Attribution-ShareAlike License</a><a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# 	</ul>
# 	<ul id="footer-places">
# 		<li id="footer-places-privacy"><a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">Privacy policy</a></li>
# 		<li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# 		<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# 		<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 		<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# 		<li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a></li>
# 		<li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Cookie_statement">Cookie statement</a></li>
# 		<li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=2013_Seattle_Seahawks_season&amp;mobileaction=toggle_view_mobile">Mobile view</a></li>
# 	</ul>
# 	<ul class="noprint" id="footer-icons">
# 		<li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88"/></a></li>
# 		<li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/poweredby_mediawiki_88x31.png" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88"/></a></li>
# 	</ul>
# 	<div style="clear: both;"></div>
# </footer>
#
#
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"1.536","walltime":"1.790","ppvisitednodes":{"value":20561,"limit":1000000},"postexpandincludesize":{"value":484145,"limit":2097152},"templateargumentsize":{"value":149595,"limit":2097152},"expansiondepth":{"value":12,"limit":40},"expensivefunctioncount":{"value":5,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":49137,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00% 1252.181      1 -total"," 27.70%  346.803     23 Template:Americanfootballbox"," 14.79%  185.217      1 Template:2013_NFC_standings"," 14.54%  182.105     20 Template:Winning_percentage"," 13.52%  169.351      3 Template:Reflist"," 11.85%  148.382    134 Template:Tooltip","  8.01%  100.303      5 Template:Cite_web","  7.09%   88.773      1 Template:Infobox_NFL_season","  6.58%   82.357      1 Template:Infobox","  6.30%   78.929      1 Template:2013_NFC_West_standings"]},"scribunto":{"limitreport-timeusage":{"value":"0.513","limit":"10.000"},"limitreport-memusage":{"value":9024182,"limit":52428800}},"cachereport":{"origin":"mw1326","timestamp":"20200619015412","ttl":2592000,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"2013 Seattle Seahawks season","url":"https:\/\/en.wikipedia.org\/wiki\/2013_Seattle_Seahawks_season","sameAs":"http:\/\/www.wikidata.org\/entity\/Q2657605","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q2657605","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2012-12-20T09:31:48Z","dateModified":"2020-05-28T11:17:15Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/5\/53\/Seattle_seahawks_uniforms_2012-2017.png","headline":"38th season in franchise history; first Super Bowl win"}</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":127,"wgHostname":"mw1321"});});</script>
# </body></html>

# %%
markup = r"""<li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>18</b></span><b> <a href="/wiki/Sidney_Rice" title="Sidney Rice">Sidney Rice</a> WR</b> <small>(IR)</small> <a class="image" href="/wiki/File:Injury_icon_2.svg"><img alt="Injury icon 2.svg" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/61/Injury_icon_2.svg/10px-Injury_icon_2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/61/Injury_icon_2.svg/15px-Injury_icon_2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/61/Injury_icon_2.svg/20px-Injury_icon_2.svg.png 2x" width="10"/></a></li>'"""
rice = BeautifulSoup(markup, 'html5lib')
rice
# Out:
# <html><head></head><body><li><span style="font-family: 'Octin Sports','Octin College','Octin Stencil','Octin Vintage','Octin Prison', 'Courier New','Courier', monospace;"><b>18</b></span><b> <a href="/wiki/Sidney_Rice" title="Sidney Rice">Sidney Rice</a> WR</b> <small>(IR)</small> <a class="image" href="/wiki/File:Injury_icon_2.svg"><img alt="Injury icon 2.svg" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/61/Injury_icon_2.svg/10px-Injury_icon_2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/61/Injury_icon_2.svg/15px-Injury_icon_2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/61/Injury_icon_2.svg/20px-Injury_icon_2.svg.png 2x" width="10"/></a></li>'</body></html>

# %%
rice = rice.next
rice
# Out:
# <b>18</b>

# %%
rice.parent.parent.name
# Out:
# 'li'

# %%
wilson = 'Wilson *	'

# %%
wilson.replace('\t', '').rstrip()
# Out:
# 'Wilson *'

# %%
'Wilson *	'
# Out:
# 'Wilson *\t'

# %%
# Out:
# '*'
